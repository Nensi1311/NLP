# %%
import csv
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.feature_extraction import _stop_words
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import keras
import seaborn as sns
sns.set(color_codes=True)

# %%
URL_tr = "https://raw.githubusercontent.com/cacoderquan/Sentiment-Analysis-on-the-Rotten-Tomatoes-movie-review-dataset/master/train.tsv";

# %%
data = pd.read_csv(URL_tr, sep='\t')

# %%
data
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# ...          ...         ...
# 156055    156056        8544
# 156056    156057        8544
# 156057    156058        8544
# 156058    156059        8544
# 156059    156060        8544
#
#                                                    Phrase  Sentiment
# 0       A series of escapades demonstrating the adage ...          1
# 1       A series of escapades demonstrating the adage ...          2
# 2                                                A series          2
# 3                                                       A          2
# 4                                                  series          2
# ...                                                   ...        ...
# 156055                                          Hearst 's          2
# 156056                          forced avuncular chortles          1
# 156057                                 avuncular chortles          3
# 156058                                          avuncular          2
# 156059                                           chortles          2
#
# [156060 rows x 4 columns]

# %%
fullSent = data.loc[data.groupby('SentenceId')['PhraseId'].idxmin()]
fullSent.head(25)
# Out:
#      PhraseId  SentenceId                                             Phrase  \
# 0           1           1  A series of escapades demonstrating the adage ...
# 63         64           2  This quiet , introspective and entertaining in...
# 81         82           3  Even fans of Ismail Merchant 's work , I suspe...
# 116       117           4  A positively thrilling combination of ethnogra...
# 156       157           5  Aggressive self-glorification and a manipulati...
# 166       167           6  A comedy-drama of nearly epic proportions root...
# 198       199           7  Narratively , Trouble Every Day is a plodding ...
# 213       214           8  The Importance of Being Earnest , so thick wit...
# 247       248           9              But it does n't leave you with much .
# 259       260          10            You could hate it for the same reason .
# 271       272          11  There 's little to recommend Snow Dogs , unles...
# 306       307          12  Kung Pow is Oedekerk 's realization of his chi...
# 352       353          13             The performances are an absolute joy .
# 363       364          14  Fresnadillo has something serious to say about...
# 407       408          15  I still like Moonlight Mile , better judgment ...
# 423       424          16  A welcome relief from baseball movies that try...
# 458       459          17  a bilingual charmer , just like the woman who ...
# 473       474          18  Like a less dizzily gorgeous companion to Mr. ...
# 516       517          19  As inept as big-screen remakes of The Avengers...
# 536       537          20  It 's everything you 'd expect -- but nothing ...
# 551       552          21                  Best indie of the year , so far .
# 563       564          22  Hatfield and Hicks make the oddest of couples ...
# 619       620          23  It 's like going to a house party and watching...
# 647       648          24  That the Chuck Norris `` grenade gag '' occurs...
# 686       687          25  The plot is romantic comedy boilerplate from s...
#
#      Sentiment
# 0            1
# 63           4
# 81           1
# 116          3
# 156          1
# 166          4
# 198          1
# 213          3
# 247          1
# 259          1
# 271          1
# 306          1
# 352          4
# 363          3
# 407          3
# 423          3
# 458          3
# 473          2
# 516          1
# 536          2
# 551          4
# 563          3
# 619          1
# 647          2
# 686          2

# %%
dist = data.groupby(["Sentiment"]).size()
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(x=dist.keys(), y=dist.values);

# %%
print(len(data.groupby('SentenceId').nunique()))
# Out:
# 8529

# %%
URL_tr = []

# %%
phrase = fullSent['Phrase']
sentiment = fullSent['Sentiment']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(phrase, sentiment, test_size=0.2, random_state=4)

# %%
print("X_train before preprocessing:", X_train)
print("Y_train before preprocessing:", Y_train)
# Out:
# X_train before preprocessing: 103322    Visually exciting sci-fi film which suffers fr...
# 32029                                          Yes , soar .
# 103055    It briefly flirts with player masochism , but ...
# 154689          This pathetic junk is barely an hour long .
# 40811     Both Grant and Hoult carry the movie because t...
#                                 ...
# 10746     Sweet Home Alabama is n't going to win any Aca...
# 113393    The film boasts dry humor and jarring shocks ,...
# 16507     Even a hardened voyeur would require the patie...
# 153434    Whether you like it or not is basically a matt...
# 25081     The rare Imax movie that you 'll wish was long...
# Name: Phrase, Length: 6823, dtype: object
# Y_train before preprocessing: 103322    2
# 32029     3
# 103055    2
# 154689    0
# 40811     3
#          ..
# 10746     3
# 113393    4
# 16507     0
# 153434    2
# 25081     3
# Name: Sentiment, Length: 6823, dtype: int64

# %%
#Data Cleaning or Preprocessing
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

temp = []

snow = nltk.stem.SnowballStemmer('english')

for sentence in phrase:
    sentence = sentence.lower() #Lowercase Conversion
    cleanr = re.compile("<.*?>")
    sentence = re.sub(cleanr, ' ', sentence) 
    sentence = re.sub(r'[?|!|\'|`|#]', r'', sentence)
    sentence = re.sub(r'[.|,|)|(|\|/]', r' ', sentence) 
    
    words = [snow.stem(word) for word in sentence.split() if word not in stopwords.words('english')] #Removing Punctuations
    temp.append(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nensi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
phrase=temp
phrase
# Out:
# [['seri',
#   'escapad',
#   'demonstr',
#   'adag',
#   'good',
#   'goos',
#   'also',
#   'good',
#   'gander',
#   'occasion',
#   'amus',
#   'none',
#   'amount',
#   'much',
#   'stori'],
#  ['quiet', 'introspect', 'entertain', 'independ', 'worth', 'seek'],
#  ['even',
#   'fan',
#   'ismail',
#   'merchant',
#   'work',
#   'suspect',
#   'would',
#   'hard',
#   'time',
#   'sit',
#   'one'],
#  ['posit',
#   'thrill',
#   'combin',
#   'ethnographi',
#   'intrigu',
#   'betray',
#   'deceit',
#   'murder',
#   'shakespearean',
#   'tragedi',
#   'juici',
#   'soap',
#   'opera'],
#  ['aggress', 'self-glorif', 'manipul', 'whitewash'],
#  ['comedy-drama',
#   'near',
#   'epic',
#   'proport',
#   'root',
#   'sincer',
#   'perform',
#   'titl',
#   'charact',
#   'undergo',
#   'midlif',
#   'crisi'],
#  ['narrat', 'troubl', 'everi', 'day', 'plod', 'mess'],
#  ['import',
#   'earnest',
#   'thick',
#   'wit',
#   'play',
#   'like',
#   'read',
#   'bartlett',
#   'familiar',
#   'quotat'],
#  ['nt', 'leav', 'much'],
#  ['could', 'hate', 'reason'],
#  ['littl',
#   'recommend',
#   'snow',
#   'dog',
#   'unless',
#   'one',
#   'consid',
#   'clich',
#   'dialogu',
#   'pervers',
#   'escap',
#   'sourc',
#   'high',
#   'hilar'],
#  ['kung',
#   'pow',
#   'oedekerk',
#   'realize',
#   'childhood',
#   'dream',
#   'martial-art',
#   'flick',
#   'prove',
#   'sometim',
#   'dream',
#   'youth',
#   'remain'],
#  ['perform', 'absolut', 'joy'],
#  ['fresnadillo',
#   'someth',
#   'serious',
#   'say',
#   'way',
#   'extravag',
#   'chanc',
#   'distort',
#   'perspect',
#   'throw',
#   'us',
#   'path',
#   'good',
#   'sens'],
#  ['still', 'like', 'moonlight', 'mile', 'better', 'judgment', 'damn'],
#  ['welcom',
#   'relief',
#   'basebal',
#   'movi',
#   'tri',
#   'hard',
#   'mythic',
#   'one',
#   'sweet',
#   'modest',
#   'ultim',
#   'win',
#   'stori'],
#  ['bilingu', 'charmer', 'like', 'woman', 'inspir'],
#  ['like',
#   'less',
#   'dizzili',
#   'gorgeous',
#   'companion',
#   'mr',
#   'wong',
#   'mood',
#   'love',
#   '--',
#   'much',
#   'hong',
#   'kong',
#   'movi',
#   'despit',
#   'mainland',
#   'set'],
#  ['inept', 'big-screen', 'remak', 'aveng', 'wild', 'wild', 'west'],
#  ['everyth', 'expect', '--', 'noth'],
#  ['best', 'indi', 'year', 'far'],
#  ['hatfield',
#   'hick',
#   'make',
#   'oddest',
#   'coupl',
#   'sens',
#   'movi',
#   'becom',
#   'studi',
#   'gambl',
#   'publish',
#   'world',
#   'offer',
#   'case',
#   'studi',
#   'exist',
#   'apart',
#   'movi',
#   'polit',
#   'ramif'],
#  ['like',
#   'go',
#   'hous',
#   'parti',
#   'watch',
#   'host',
#   'defend',
#   'froth',
#   'ex-girlfriend'],
#  ['chuck',
#   'norri',
#   'grenad',
#   'gag',
#   'occur',
#   '7',
#   'time',
#   'windtalk',
#   'good',
#   'indic',
#   'serious-mind',
#   'film'],
#  ['plot', 'romant', 'comedi', 'boilerpl', 'start', 'finish'],
#  ['arriv',
#   'impecc',
#   'pedigre',
#   'mongrel',
#   'pep',
#   'almost',
#   'indecipher',
#   'plot',
#   'complic'],
#  ['film', 'clear', 'mean', 'preach', 'exclus', 'convert'],
#  ['import',
#   'earnest',
#   'offer',
#   'opportun',
#   'occasion',
#   'smile',
#   'chuckl',
#   'nt',
#   'give',
#   'us',
#   'reason',
#   'theater',
#   'beyond',
#   'wild',
#   'wit',
#   'actor',
#   'perform'],
#  ['latest',
#   'vapid',
#   'actor',
#   'exercis',
#   'appropri',
#   'structur',
#   'arthur',
#   'schnitzler',
#   'reigen'],
#  ['vaudevill',
#   'show',
#   'well-construct',
#   'narrat',
#   'term',
#   'inoffens',
#   'actual',
#   'rather',
#   'sweet'],
#  ['noth', 'run-of-the-mil', 'action', 'flick'],
#  ['hamper',
#   '--',
#   'paralyz',
#   '--',
#   'self-indulg',
#   'script',
#   'aim',
#   'poetri',
#   'end',
#   'sound',
#   'like',
#   'satir'],
#  ['ice',
#   'age',
#   'first',
#   'computer-gener',
#   'featur',
#   'cartoon',
#   'feel',
#   'like',
#   'movi',
#   'make',
#   'glacial',
#   'pace',
#   'earli'],
#  ['littl', 'sens', 'go', 'maker', 'serv', 'clich', 'consider', 'dash'],
#  ['cattaneo',
#   'follow',
#   'runaway',
#   'success',
#   'first',
#   'film',
#   'full',
#   'monti',
#   'someth',
#   'differ'],
#  ['unnam',
#   'easili',
#   'substitut',
#   'forc',
#   'serv',
#   'whatev',
#   'terror',
#   'hero',
#   'horror',
#   'movi',
#   'tri',
#   'avoid'],
#  ['almost', 'feel', 'movi', 'interest', 'entertain', 'amus', 'us'],
#  ['movi',
#   'progress',
#   'rambl',
#   'incoher',
#   'give',
#   'new',
#   'mean',
#   'phrase',
#   'fatal',
#   'script',
#   'error'],
#  ['nt',
#   'judg',
#   'one',
#   'soon',
#   '-',
#   'dark',
#   'gritti',
#   'stori',
#   'take',
#   'total',
#   'unexpect',
#   'direct',
#   'keep',
#   'go'],
#  ['could', 'young', 'romant', 'date'],
#  ['tartakovski',
#   'team',
#   'freakish',
#   'power',
#   'visual',
#   'charm',
#   'five',
#   'writer',
#   'slip',
#   'modern',
#   'rut',
#   'narrat',
#   'banal'],
#  ['vincent',
#   'gallo',
#   'right',
#   'home',
#   'french',
#   'shocker',
#   'play',
#   'usual',
#   'bad',
#   'boy',
#   'weirdo',
#   'role'],
#  ['horror',
#   'movi',
#   'primari',
#   'goal',
#   'frighten',
#   'disturb',
#   'work',
#   'spectacular',
#   'well',
#   'shiver-induc',
#   'nerve-rattl',
#   'ride'],
#  ['100-minut', 'movi', '25', 'minut', 'decent', 'materi'],
#  ['fortun', 'still', 'option'],
#  ['less',
#   'sensat',
#   'true-crim',
#   'hell-jaunt',
#   'purist',
#   'might',
#   'like',
#   'experiment',
#   'storytel',
#   '-lrb-',
#   'though',
#   'less',
#   'horrifi',
#   '-rrb-'],
#  ['tricki',
#   'satisfi',
#   'david',
#   'mamet',
#   'airless',
#   'cinemat',
#   'shell',
#   'game'],
#  ['sure', 'filmmak', 'would', 'disagre', 'honest', 'nt', 'see', 'point'],
#  ['jone',
#   'tackl',
#   'meati',
#   'subject',
#   'drawn',
#   'engag',
#   'charact',
#   'pepper',
#   'page',
#   'memor',
#   'zinger'],
#  ['bloodi',
#   'sunday',
#   'grace',
#   'call',
#   'prevent',
#   'rather',
#   'place',
#   'blame',
#   'make',
#   'one',
#   'best',
#   'war',
#   'movi',
#   'ever',
#   'made'],
#  ['take',
#   'clunki',
#   'tv-movi',
#   'approach',
#   'detail',
#   'chapter',
#   'life',
#   'celebr',
#   'irish',
#   'playwright',
#   'poet',
#   'drinker'],
#  ['final',
#   'come',
#   'miramax',
#   'deep',
#   'shelv',
#   'coupl',
#   'abort',
#   'attempt',
#   'wake',
#   'reno',
#   'make',
#   'strong',
#   'case',
#   'let',
#   'sleep',
#   'dog',
#   'lie'],
#  ['thank',
#   'larg',
#   'william',
#   'interest',
#   'develop',
#   'process',
#   '60',
#   'minut',
#   '--',
#   'rest',
#   'overexpos',
#   'wast',
#   'film'],
#  ['come',
#   'across',
#   'relic',
#   'bygon',
#   'era',
#   'convolut',
#   'feel',
#   'silli',
#   'rather',
#   'plausibl'],
#  ['perhap', 'clich', 'call', 'film', 'refresh'],
#  ['lead', 'perform', 'oscar-s'],
#  ['run', 'live'],
#  ['mark',
#   'pellington',
#   'latest',
#   'pop',
#   'thriller',
#   'kooki',
#   'overeag',
#   'spooki',
#   'subt',
#   'love',
#   'myth'],
#  ['claud',
#   'chabrol',
#   'camera',
#   'way',
#   'gentl',
#   'sway',
#   'back',
#   'forth',
#   'cradl',
#   'charact',
#   'veil',
#   'tension',
#   'beneath',
#   'otherwis',
#   'tender',
#   'movement'],
#  ['transform',
#   'one',
#   '-lrb-',
#   'shakespear',
#   '-rrb-',
#   'deepest',
#   'tragedi',
#   'smart',
#   'new',
#   'comedi'],
#  ['screenplay',
#   'jame',
#   'eric',
#   'jame',
#   'horton',
#   'director',
#   'peter',
#   'ofallon',
#   'pat',
#   'make',
#   'teeth',
#   'hurt'],
#  ['arriv',
#   'particular',
#   'dark',
#   'moment',
#   'histori',
#   'offer',
#   'flicker',
#   'remind',
#   'tie',
#   'bind',
#   'us'],
#  ['generic',
#   'villain',
#   'lack',
#   'intrigu',
#   '-lrb-',
#   'funni',
#   'accent',
#   '-rrb-',
#   'action',
#   'scene',
#   'poor',
#   'deliv'],
#  ['charact', 'deepli', 'thought', 'right-think', 'film'],
#  ['film',
#   'despit',
#   'gratuit',
#   'cinemat',
#   'distract',
#   'impress',
#   'upon',
#   'still',
#   'good',
#   'fun'],
#  ['downright',
#   'transpar',
#   'script',
#   'endless',
#   'assault',
#   'embarrass',
#   'ham-fist',
#   'sex',
#   'joke',
#   'reek',
#   'script',
#   'rewrit',
#   'design',
#   'garner',
#   'film',
#   'cooler',
#   'pg-13',
#   'rate'],
#  ['smart',
#   'provoc',
#   'drama',
#   'near',
#   'imposs',
#   ':',
#   'get',
#   'skin',
#   'man',
#   'know',
#   'evil',
#   'monstrous',
#   'lunat'],
#  ['like', 'drive-bi'],
#  ['mani',
#   'thing',
#   '--',
#   'stoner',
#   'midnight',
#   'flick',
#   'sci-fi',
#   'deconstruct',
#   'gay',
#   'fantasia',
#   '--',
#   'love',
#   'stori',
#   'sanguin',
#   'titl'],
#  ['funni',
#   'romant',
#   'comedi',
#   'two',
#   'skittish',
#   'new',
#   'york',
#   'middle-ag',
#   'stumbl',
#   'relationship',
#   'struggl',
#   'furious',
#   'fear',
#   'foibl'],
#  ['ambit', 'say', 'someth', 'subject', 'willing'],
#  ['-lrb-',
#   'scherfig',
#   '-rrb-',
#   'made',
#   'movi',
#   'leav',
#   'wonder',
#   'charact',
#   'live',
#   'clever',
#   'credit',
#   'roll'],
#  ['-lrb-', '-rrb-', 'absorb', 'documentari'],
#  ['reek', 'rot', 'hack', 'work', 'start', 'finish'],
#  ['play',
#   'like',
#   'seri',
#   'vignett',
#   '--',
#   'clip',
#   'film',
#   'still',
#   'look',
#   'common',
#   'through-lin'],
#  [],
#  ['major',
#   'problem',
#   'windtalk',
#   'bulk',
#   'movi',
#   'center',
#   'wrong',
#   'charact'],
#  ['swimfan',
#   'like',
#   'fatal',
#   'attract',
#   'eventu',
#   'goe',
#   'overboard',
#   'looni',
#   'melodramat',
#   'denouement',
#   'high',
#   'school',
#   'swim',
#   'pool',
#   'substitut',
#   'bathtub'],
#  ['heartfelt', 'stori', 'nt', 'involv', 'one'],
#  ['unsettl', 'memor', 'cinemat', 'experi', 'predecessor', 'proud'],
#  ['pretti',
#   'good',
#   'execut',
#   'stori',
#   'lot',
#   'richer',
#   'one',
#   'hollywood',
#   'action',
#   'screenwrit',
#   'usual',
#   'come'],
#  ['phillip',
#   'noyc',
#   'actor',
#   '--',
#   'well',
#   'cinematograph',
#   'christoph',
#   'doyl',
#   '--',
#   'understand',
#   'delic',
#   'forc',
#   'green',
#   'prose',
#   'screen',
#   'version',
#   'quiet',
#   'american'],
#  ['pianist',
#   'lack',
#   'quick',
#   'emot',
#   'connect',
#   'steven',
#   'spielberg',
#   'schindler',
#   'list'],
#  ['invent', 'fun', 'intox', 'sexi', 'violent', 'self-indulg', 'madden'],
#  ['tell', 'fascin', 'compel', 'stori'],
#  ['written',
#   'flat',
#   'david',
#   'kendal',
#   'direct',
#   'bare',
#   'someth',
#   'mari',
#   'co-writ',
#   'ed',
#   'decter'],
#  ['high',
#   'recommend',
#   'view',
#   'courag',
#   'idea',
#   'technic',
#   'profici',
#   'great',
#   'act'],
#  ['imax', 'short', 'wonder', 'big', 'screen'],
#  ['show', 'us', 'slice', 'life', 'differ', 'yet', 'instant', 'recogniz'],
#  ['amid',
#   'shock',
#   'curios',
#   'factor',
#   'film',
#   'corni',
#   'examin',
#   'young',
#   'actress',
#   'tri',
#   'find',
#   'way'],
#  ['lazi',
#   'movi',
#   'avoid',
#   'solv',
#   'one',
#   'problem',
#   'tri',
#   'distract',
#   'us',
#   'solut',
#   'anoth'],
#  ['comprehens', 'dummi', 'guid', 'someth', 'even', 'non-techi', 'enjoy'],
#  ['entertain',
#   'much',
#   'music',
#   'comic',
#   'antic',
#   'pervers',
#   'pleasur',
#   'watch',
#   'disney',
#   'scrape',
#   'bottom',
#   'cracker',
#   'barrel'],
#  ['writer\\',
#   'director',
#   'burr',
#   'steer',
#   'emphas',
#   'q',
#   'quirki',
#   'mix',
#   'result'],
#  ['scarc',
#   'worth',
#   'mention',
#   'apart',
#   'report',
#   'number',
#   'tumblewe',
#   'blow',
#   'empti',
#   'theatr',
#   'grace',
#   'compani'],
#  ['invigor', 'surreal', 'reson', 'rainbow', 'emot'],
#  ['analyz',
#   'one',
#   'crass',
#   'contriv',
#   'sequel',
#   'fail',
#   'make',
#   'second-guess',
#   'affect',
#   'origin'],
#  ['report',
#   'card',
#   ':',
#   'nt',
#   'live',
#   'exalt',
#   'taglin',
#   '-',
#   'definit',
#   'room',
#   'improv'],
#  ['particular', 'good', 'film', 'neither', 'monster', 'one'],
#  ['tsai', 'may', 'plough', 'furrow', 'often'],
#  ['-lrb-',
#   'green',
#   '-rrb-',
#   'comedi',
#   'equival',
#   'saddam',
#   'hussein',
#   'readi',
#   'go',
#   'u',
#   'n',
#   'ask',
#   'permiss',
#   'preemptiv',
#   'strike'],
#  ['surpris',
#   'solid',
#   'achiev',
#   'director',
#   'malcolm',
#   'lee',
#   'writer',
#   'john',
#   'ridley'],
#  ['massoud',
#   'stori',
#   'epic',
#   'also',
#   'tragedi',
#   'record',
#   'tenaci',
#   'human',
#   'fighter',
#   'also',
#   'prison',
#   '-lrb-',
#   'ultim',
#   'victim',
#   '-rrb-',
#   'histori'],
#  ['chang', 'lane', 'tri'],
#  ['shyamalan', 'stop', 'tri', 'pleas', 'mom'],
#  ['macabr',
#   'styliz',
#   'swedish',
#   'fillm',
#   'modern',
#   'citi',
#   'religi',
#   'civic',
#   'virtu',
#   'hold',
#   'societi',
#   'place',
#   'tatter'],
#  ['one',
#   'recent',
#   'memori',
#   'thought',
#   'film',
#   'art',
#   'ethic',
#   'cost',
#   'moral',
#   'compromis'],
#  ['narrat',
#   'consist',
#   'unimagin',
#   'probabl',
#   'way',
#   'save',
#   'film',
#   'aid',
#   'wisecrack',
#   'mysteri',
#   'scienc',
#   'theater',
#   '3000',
#   'guy'],
#  ['filmmak',
#   'tian',
#   'zhuangzhuang',
#   'triumphant',
#   'return',
#   'narrat',
#   'filmmak',
#   'visual',
#   'master',
#   'work',
#   'quiet',
#   'power'],
#  ['mawkish',
#   'self-parodi',
#   'play',
#   'like',
#   'weird',
#   'masterpiec',
#   'theater',
#   'sketch',
#   'neither',
#   'point',
#   'view',
#   'compel',
#   'reason'],
#  ['take',
#   'one',
#   'charact',
#   'nt',
#   'like',
#   'anoth',
#   'nt',
#   'believ',
#   'put',
#   'battl',
#   'will',
#   'imposs',
#   'care',
#   'nt',
#   'funni'],
#  ['appreci',
#   'one-sid',
#   'theme',
#   'lawrenc',
#   'over-indulg',
#   'tirad',
#   'knock',
#   'enjoy',
#   'big',
#   'screen',
#   'postcard',
#   'self-glorifi',
#   'martin',
#   'lawrenc',
#   'lovefest'],
#  ['whole',
#   'film',
#   'sneaki',
#   'feel',
#   '--',
#   'director',
#   'tri',
#   'dupe',
#   'viewer',
#   'take',
#   'import',
#   'simpli',
#   'movi',
#   'ugli',
#   'look',
#   'hollywood',
#   'product'],
#  ['whenev',
#   'threaten',
#   'get',
#   'bog',
#   'earnest',
#   'dramaturgi',
#   'stir',
#   'visual',
#   'sequenc',
#   'like',
#   'surg',
#   'swirl',
#   'rapid',
#   'leap',
#   'pinnacl',
#   'pinnacl',
#   'rous',
#   'us'],
#  ['swing', 'film', 'make', 'seem', 'hobbi', 'attract', 'young', 'fit'],
#  ['entir', 'unprepar'],
#  ['devo',
#   'deliv',
#   'perfect',
#   'perform',
#   'captur',
#   'innoc',
#   'bud',
#   'demon',
#   'within',
#   'wallflow'],
#  ['300',
#   'year',
#   'russian',
#   'histori',
#   'cultur',
#   'compress',
#   'evanesc',
#   'seamless',
#   'sumptuous',
#   'stream',
#   'conscious'],
#  ['filmmak',
#   'want',
#   'noth',
#   'els',
#   'show',
#   'us',
#   'good',
#   'time',
#   'cheap',
#   'b',
#   'movi',
#   'way',
#   'succeed'],
#  ['mr',
#   'polanski',
#   'element',
#   ':',
#   'alon',
#   'abandon',
#   'still',
#   'consol',
#   'art',
#   'ever',
#   'reveal',
#   'sourc',
#   'spiritu',
#   'surviv'],
#  ['spider-man',
#   'better',
#   'summer',
#   'blockbust',
#   'endur',
#   'last',
#   'summer',
#   'hope',
#   'set',
#   'tone',
#   'summer',
#   'good',
#   'stuff'],
#  ['absorb', 'charact'],
#  ['violent', 'vulgar', 'forgett', 'entertain'],
#  ['unsettl',
#   'imag',
#   'war-ravag',
#   'land',
#   'prove',
#   'potent',
#   'rivet',
#   'unlik',
#   'stori',
#   'sarah',
#   'harrison'],
#  ['wind',
#   'revelatori',
#   'narcissist',
#   'achiev',
#   'honest',
#   'insight',
#   'relationship',
#   'high-concept',
#   'film',
#   'candy-coat',
#   'pat',
#   'storylin',
#   'precious',
#   'circumst',
#   'beauti',
#   'star'],
#  ['most',
#   'martha',
#   'most',
#   'unsurpris',
#   'still',
#   'sweet',
#   'even',
#   'delect',
#   'divers'],
#  ['thought',
#   'surpris',
#   'affect',
#   'portrait',
#   'screwed-up',
#   'man',
#   'dare',
#   'mess',
#   'power',
#   'peopl',
#   'seen',
#   'eye',
#   'idealist',
#   'kid',
#   'choos',
#   'champion',
#   'ultim',
#   'lose',
#   'caus'],
#  ['keen',
#   'observ',
#   'refresh',
#   'natur',
#   'swim',
#   'get',
#   'detail',
#   'right',
#   'promenad',
#   'bare',
#   'clad',
#   'bodi',
#   'myrtl',
#   'beach',
#   'c',
#   'adrenalin',
#   'jolt',
#   'sudden',
#   'lunch',
#   'rush',
#   'diner'],
#  ['brilliant', 'gag', 'expens', 'paid', 'pay', 'see'],
#  ['triumph',
#   'film',
#   'hew',
#   'world',
#   'carri',
#   'us',
#   'effortless',
#   'dark',
#   'light'],
#  ['everyon', 'involv', 'seem', 'coast'],
#  ['fascin',
#   'dark',
#   'thriller',
#   'keep',
#   'hook',
#   'delici',
#   'pulpi',
#   'lurid',
#   'fiction'],
#  ['suspect',
#   'kind',
#   'product',
#   'would',
#   'funnier',
#   'director',
#   'releas',
#   'outtak',
#   'theatric',
#   'use',
#   'film',
#   'bonus',
#   'featur',
#   'dvd'],
#  ['hard', 'say', 'might', 'enjoy', 'tolstoy', 'groupi'],
#  ['daughter',
#   'danang',
#   'reveal',
#   'effort',
#   'toward',
#   'closur',
#   'open',
#   'new',
#   'wound'],
#  ['one', 'year', 'weird', 'engag', 'unpredict', 'charact', 'piec'],
#  ['intrigu', 'downright', 'intox'],
#  ['although',
#   'fair',
#   'involv',
#   'far',
#   'goe',
#   'film',
#   'nt',
#   'end',
#   'much',
#   'fresh',
#   'say',
#   'grow',
#   'cathol',
#   'realli',
#   'anyth'],
#  ['movi',
#   'silli',
#   'beyond',
#   'comprehens',
#   'even',
#   'nt',
#   'silli',
#   'would',
#   'still',
#   'beyond',
#   'comprehens'],
#  ['sleek', 'arti'],
#  ['poor',
#   'edit',
#   'bad',
#   'bluescreen',
#   'ultra-cheesi',
#   'dialogu',
#   'highlight',
#   'radic',
#   'action'],
#  ['-lrb-',
#   'cho',
#   'face',
#   '-rrb-',
#   'amaz',
#   'slapstick',
#   'instrument',
#   'creat',
#   'scrapbook',
#   'live',
#   'mug',
#   'shot'],
#  ['get', 'detail', 'time', 'frame', 'right', 'complet', 'miss', 'emot'],
#  ['initi',
#   'strang',
#   'inexor',
#   'give',
#   'way',
#   'rote',
#   'sentiment',
#   'mystic',
#   'tender',
#   'becom',
#   'narrat',
#   'expedi'],
#  ['let', 'brush', 'human', 'psycho', 'without', 'make', 'less', 'psycho'],
#  ['like',
#   'world',
#   'film',
#   'hartley',
#   'creat',
#   'monster',
#   'nt',
#   'know',
#   'handl'],
#  ['cower',
#   'beg',
#   'feet',
#   'scruffi',
#   'giannini',
#   'madonna',
#   'give',
#   'best',
#   'perform',
#   'sinc',
#   'abel',
#   'ferrara',
#   'beaten',
#   'pulp',
#   'danger',
#   'game'],
#  ['clumsi', 'key', 'moment', 'make', 'big', 'splash'],
#  ['eight',
#   'leg',
#   'freak',
#   'part',
#   'homag',
#   'tarantula',
#   'low',
#   '-',
#   'budget',
#   'b-movi',
#   'thriller',
#   '1950s',
#   '60s',
#   'movi',
#   'silli',
#   '-lrb-',
#   'sophomor',
#   '-rrb-',
#   'romp',
#   'horror',
#   'hellish',
#   'condit'],
#  ['feel',
#   'like',
#   'light',
#   'errol',
#   'morri',
#   'focus',
#   'eccentr',
#   'fail',
#   'ultim',
#   'make',
#   'someth',
#   'bigger',
#   'scrapbook',
#   'oddbal'],
#  ['spielberg', 'realize', 'near-futur', 'america', 'master'],
#  ['scientif',
#   'law',
#   'discern',
#   'produc',
#   'would',
#   'well',
#   'heed',
#   ':',
#   'mediocr',
#   'movi',
#   'start',
#   'drag',
#   'soon',
#   'action',
#   'speed',
#   ';',
#   'explos',
#   'start',
#   'fall',
#   'piec'],
#  ['one', 'cool', 'actor', 'never', 'seem', 'awar', 'cool'],
#  ['feel',
#   'like',
#   'work',
#   'artist',
#   'simpli',
#   'tire',
#   '--',
#   'fight',
#   'fight',
#   'put',
#   'weight',
#   'world',
#   'shoulder',
#   'play',
#   'narrat',
#   'form'],
#  ['stale', 'uninspir'],
#  ['director',
#   'cut',
#   'film',
#   'love',
#   'song',
#   'movi',
#   'also',
#   'fulli',
#   'exampl',
#   'kind',
#   'lush',
#   'all-envelop',
#   'movi',
#   'experi',
#   'rhapsod'],
#  ['rare', 'capabl', 'sooth', 'break', 'heart', 'singl', 'stroke'],
#  ['eerili', 'accur', 'depict', 'depress'],
#  ['feature-length', 'film', 'wear', 'welcom', 'tri', 'titl', 'charact'],
#  ['unclutt',
#   'reson',
#   'gem',
#   'relay',
#   'univers',
#   'point',
#   'without',
#   'lectur',
#   'confront'],
#  ['stori', 'alon', 'could', 'forc', 'scratch', 'hole', 'head'],
#  ['filmmak',
#   'post-camp',
#   'comprehens',
#   'made',
#   'old-tim',
#   'b',
#   'movi',
#   'good-bad',
#   'make',
#   'eight',
#   'leg',
#   'freak',
#   'perfect',
#   'entertain',
#   'summer',
#   'divers'],
#  ['creature-featur',
#   'fan',
#   'know',
#   'cross',
#   'toxic',
#   'chemic',
#   'bunch',
#   'exot',
#   'creatur',
#   'get',
#   'lot',
#   'run',
#   'around',
#   'scream',
#   'death'],
#  ['bet', 'make', 'rather', 'convolut', 'journey', 'worth', 'take'],
#  ['take',
#   'sudden',
#   'turn',
#   'devolv',
#   'bizarr',
#   'sort',
#   'romant',
#   'comedi',
#   'steven',
#   'shainberg',
#   'adapt',
#   'mari',
#   'gaitskil',
#   'harrow',
#   'short',
#   'stori',
#   'brilliant',
#   'play',
#   'deepli',
#   'unsettl',
#   'experi'],
#  ['kim',
#   'ki-deok',
#   'seem',
#   'mind',
#   '-lrb-',
#   'emot',
#   'least',
#   '-rrb-',
#   'adolesc',
#   'audienc',
#   'demand',
#   'regular',
#   'shock',
#   'bout',
#   'bare',
#   'defens',
#   'sexual',
#   'violenc',
#   'keep',
#   'interest'],
#  ['reason',
#   'exist',
#   'employ',
#   'hollywood',
#   'kid',
#   'peopl',
#   'owe',
#   'favor',
#   'famous',
#   'parent'],
#  ['well-mad',
#   'emot',
#   'scatter',
#   'film',
#   'whose',
#   'hero',
#   'give',
#   'heart',
#   'dog'],
#  ['love',
#   'cinema',
#   'paradiso',
#   'find',
#   'new',
#   'scene',
#   'interest',
#   'find',
#   'movi',
#   'improv'],
#  ['campanella',
#   'get',
#   'tone',
#   'right',
#   '--',
#   'funni',
#   'middl',
#   'sad',
#   'middl',
#   'hope'],
#  ['noth',
#   'amiabl',
#   'unfocus',
#   'bagatell',
#   'play',
#   'like',
#   'loosely-connect',
#   'string',
#   'acting-workshop',
#   'exercis'],
#  ['sharp', 'movi', 'otherwis', 'dull', 'subject'],
#  ['wallac',
#   'get',
#   'bit',
#   'heavi',
#   'hand',
#   'messag',
#   'time',
#   'visual',
#   'flair',
#   'wax',
#   'poetic',
#   'far',
#   'much',
#   'tast'],
#  ['charm', 'funni', '-lrb-', 'ultim', 'silli', '-rrb-', 'movi'],
#  ['one',
#   'thing',
#   'wild',
#   'film',
#   'imax',
#   'film',
#   'nt',
#   ':',
#   'chimp',
#   'lot',
#   'chimp',
#   'blown',
#   'size',
#   'hous'],
#  ['start',
#   'mediocr',
#   'spiral',
#   'downward',
#   'thud',
#   'bottom',
#   'pool',
#   'utter',
#   'incompet',
#   'conclus'],
#  ['children', 'film', 'truest', 'sens'],
#  ['horrend',
#   'amateurish',
#   'filmmak',
#   'plain',
#   'dull',
#   'visual',
#   'ugli',
#   'nt',
#   'incomprehens'],
#  ['beauti',
#   'craft',
#   'engag',
#   'filmmak',
#   'attract',
#   'upscal',
#   'audienc',
#   'hungri',
#   'qualiti',
#   'nostalg',
#   'twisti',
#   'yarn',
#   'keep',
#   'guess'],
#  ['awkward', 'contriv', 'exercis', 'magic', 'realism'],
#  ['punch', 'line', 'miss', 'unfortun', 'outnumb', 'hit', 'three-to-on'],
#  ['like',
#   'smoke',
#   'signal',
#   'film',
#   'also',
#   'imbu',
#   'strong',
#   'theme',
#   'famili',
#   'tie',
#   'spiritu',
#   'power',
#   'move',
#   'without',
#   'stoop',
#   'base',
#   'melodrama'],
#  ['evok',
#   'style',
#   'flash',
#   'double-cross',
#   'made',
#   'mamet',
#   'hous',
#   'game',
#   'last',
#   'fall',
#   'heist',
#   'much',
#   'fun'],
#  ['film', 'aim', 'funni', 'uplift', 'move', 'sometim'],
#  ['brief', '42', 'minut', 'need', 'x', 'less', 'blab'],
#  ['spald', 'gray', 'equival', 'teen', 'gross-out', 'comedi'],
#  ['great', 'deal', 'corni', 'dialogu', 'preposter', 'moment'],
#  ['uneven', 'lot', 'fun'],
#  ['result', 'might', 'look', 'like', 'vulgar'],
#  ['film',
#   'rehash',
#   'sever',
#   'old',
#   'theme',
#   'cap',
#   'pointless',
#   'extrem',
#   '--',
#   'insan',
#   'violent',
#   'graphic'],
#  ['dragon', 'real', 'star', 'reign', 'fire', 'wo', 'nt', 'disappoint'],
#  ['never', 'play', 'dramat', 'even', 'dramat', 'thing', 'happen', 'peopl'],
#  ['manag',
#   'pleas',
#   'intend',
#   'audienc',
#   '--',
#   'children',
#   '--',
#   'without',
#   'place',
#   'parent',
#   'coma-lik',
#   'state'],
#  ['movi',
#   'generat',
#   'plot',
#   'point',
#   'degre',
#   'random',
#   'usual',
#   'achiev',
#   'lotteri',
#   'draw'],
#  ['though',
#   'film',
#   'never',
#   'veer',
#   'comic',
#   'cours',
#   'unintent',
#   'parallel',
#   'might',
#   'inadvert',
#   'evok',
#   'memori',
#   'emot',
#   'anyth',
#   'humor'],
#  ['film', 'depress', 'life'],
#  ['saw', 'tv', 'probabl', 'turn', 'convinc', 'alreadi', 'seen', 'movi'],
#  ['get',
#   'impress',
#   'writer',
#   'director',
#   'burr',
#   'steer',
#   'know',
#   'territori',
#   'sens',
#   'humor',
#   'yet',
#   'lose',
#   'smug',
#   'self-satisfact',
#   'usual',
#   'associ',
#   'better',
#   'privat',
#   'school'],
#  ['superior', 'horror', 'flick'],
#  ['movi',
#   'heavy-hand',
#   'screenplay',
#   'navig',
#   'fast',
#   'fade',
#   'pompos',
#   'pretenti'],
#  ['littl', 'weak', '--', 'nt', 'funni'],
#  ['nt', 'fit', 'well', 'togeth', 'neither', 'well', 'told'],
#  ['latent', 'gay', 'like', 'read', 'hard', 'enough'],
#  ['sophist', 'liter', 'pictur', 'usual', 'amus', 'littl', 'catch'],
#  ['storytel', 'feel', 'slight'],
#  ['mont',
#   'cristo',
#   'smart',
#   'emphas',
#   'well-wrought',
#   'stori',
#   'omit',
#   'needless',
#   'chase',
#   'scene',
#   'swordfight',
#   'reveng',
#   'unfold'],
#  ['fairi',
#   'tale',
#   'come',
#   'renown',
#   'indian',
#   'film',
#   'cultur',
#   'allow',
#   'american',
#   'final',
#   'revel',
#   'splendor'],
#  ['well-don',
#   'supernatur',
#   'thriller',
#   'keen',
#   'insight',
#   'parapsycholog',
#   'phenomena',
#   'soul',
#   'nuanc',
#   'griev',
#   'process'],
#  ['bond',
#   'save',
#   'us',
#   'latest',
#   'eccentr',
#   'super-wealthi',
#   'megalomaniac',
#   'bent',
#   'world',
#   'domin',
#   'destruct'],
#  ['depress',
#   'ruthless',
#   'pain',
#   'deprav',
#   'movi',
#   'equival',
#   'stare',
#   'open',
#   'wound'],
#  ['damon',
#   'bring',
#   'proper',
#   'convict',
#   'role',
#   '-lrb-',
#   'jason',
#   'bourn',
#   '-rrb-'],
#  ['parent', 'bewar', ';', 'downright', 'movi', 'penanc'],
#  ['rich', 'luscious', 'care'],
#  ['singular', 'off-put', 'romant', 'comedi'],
#  ['director',
#   'bori',
#   'von',
#   'sychowski',
#   'instead',
#   'opt',
#   'routin',
#   'slasher',
#   'film',
#   'probabl',
#   'fun',
#   'make',
#   'sit'],
#  ['would',
#   'nice',
#   'screenwrit',
#   'trust',
#   'audienc',
#   'understand',
#   'complex',
#   'stori',
#   'left',
#   'film',
#   'predict',
#   'denouement'],
#  ['superflu',
#   'sequel',
#   'plagu',
#   'old',
#   'familiar',
#   'feel',
#   'let',
#   'get',
#   'thing',
#   ':',
#   'everyon',
#   'shown',
#   'appoint',
#   'time',
#   'place',
#   'visibl',
#   'enthusiasm',
#   'mighti',
#   'hard',
#   'find'],
#  ['earnest',
#   'roughshod',
#   'document',
#   'serv',
#   'workabl',
#   'primer',
#   'region',
#   'recent',
#   'histori',
#   'would',
#   'make',
#   'terrif',
#   '10th-grade',
#   'learn',
#   'tool'],
#  ['cloak',
#   'familiar',
#   'anti-feminist',
#   'equat',
#   '-lrb-',
#   'career',
#   '-',
#   'kid',
#   '=',
#   'miseri',
#   '-rrb-',
#   'tiresom',
#   'romantic-comedi',
#   'dud'],
#  ['film',
#   'play',
#   'thing',
#   'nice',
#   'n',
#   'safe',
#   'often',
#   'play',
#   'like',
#   'milquetoast',
#   'movi',
#   'week',
#   'blown',
#   'big',
#   'screen'],
#  ['work', 'transcend', 'boy-meets-girl', 'postur', 'typic', 'love', 'stori'],
#  ['even', 'predict', 'cliche-ridden', 'endeavor', 'predecessor'],
#  ['play',
#   'like',
#   'bad',
#   'blend',
#   'overrip',
#   'episod',
#   'tv',
#   'dawson',
#   'creek',
#   'recycl',
#   'dumbed-down',
#   'version',
#   'love',
#   'stori'],
#  ['script',
#   'cover',
#   'huge',
#   'heavi',
#   'topic',
#   'bland',
#   'surfacey',
#   'way',
#   'nt',
#   'offer',
#   'insight',
#   'instanc',
#   'good',
#   'thing',
#   'happen',
#   'bad',
#   'peopl'],
#  ['film', 'bad', 'nt', 'improv', 'upon', 'experi', 'stare', 'blank', 'screen'],
#  ['threw',
#   'load',
#   'money',
#   'idea',
#   'much',
#   'even',
#   'made',
#   'teenag',
#   'boy',
#   'wrestl',
#   'fan'],
#  ['difficult',
#   'imagin',
#   'confus',
#   'less',
#   'interest',
#   'sloppili',
#   'made',
#   'film',
#   'could',
#   'possibl',
#   'come',
#   'road',
#   '2002'],
#  ['though',
#   'film',
#   'well-intent',
#   'one',
#   'could',
#   'rent',
#   'origin',
#   'get',
#   'love',
#   'stori',
#   'parabl'],
#  ['jolt',
#   'charleston',
#   'rhythm',
#   'stori',
#   'sizzl',
#   'old',
#   'news',
#   'final',
#   'found',
#   'right',
#   'vent',
#   '-lrb-',
#   'accur'],
#  [],
#  ['william',
#   'play',
#   'sy',
#   'anoth',
#   'open-fac',
#   'smile',
#   'madmen',
#   'like',
#   'killer',
#   'insomnia'],
#  ['phoned-in', 'busi', 'usual'],
#  ['lackadais',
#   'plot',
#   'mindless',
#   'action',
#   'benjamin',
#   'evok',
#   'bottom',
#   'tier',
#   'blaxploit',
#   'flick',
#   '1970s'],
#  ['ah', 'yes', 'would', ':', 'fight', 'urg', 'doze'],
#  ['thoughtless',
#   'random',
#   'superfici',
#   'humour',
#   'lot',
#   'bad',
#   'scous',
#   'accent'],
#  ['era',
#   'big',
#   'star',
#   'high',
#   'product',
#   'valu',
#   'standard',
#   'procedur',
#   'narc',
#   'strike',
#   'defiant',
#   'retro',
#   'chord',
#   'outpac',
#   'contemporari',
#   'dare',
#   'verv'],
#  ['rip-roar', 'comedi', 'action', 'fest', 'put', 'hair', 'chest'],
#  ['thought', 'what-if', 'heart', 'well', 'mind'],
#  ['miyazaki',
#   'one',
#   'world',
#   'cinema',
#   'wondrous',
#   'gift',
#   'artist',
#   'storytel'],
#  ['chronicl',
#   'one',
#   'man',
#   'quest',
#   'presid',
#   'man',
#   'single-hand',
#   'turn',
#   'plane',
#   'full',
#   'hard-bitten',
#   'cynic',
#   'journalist',
#   'essenti',
#   'campaign',
#   'end',
#   'extend',
#   'public',
#   'depart'],
#  ['provid',
#   'kind',
#   'laugh',
#   'therapi',
#   'need',
#   'movi',
#   'comedi',
#   '--',
#   'offbeat',
#   'humor',
#   'amus',
#   'charact',
#   'happi',
#   'end'],
#  ['feel', 'strang', 'hollow', 'emot', 'core'],
#  ['time',
#   'commerci',
#   'squeez',
#   'life',
#   'whatev',
#   'ideal',
#   'american',
#   'moviemak',
#   'ever',
#   'godfrey',
#   'reggio',
#   'career',
#   'shine',
#   'like',
#   'lone',
#   'beacon'],
#  ['director',
#   'roger',
#   'michel',
#   'mani',
#   'littl',
#   'thing',
#   'right',
#   'difficult',
#   'cuss',
#   'sever',
#   'bungl',
#   'big',
#   'stuff'],
#  ['robert',
#   'harmon',
#   'less-is-mor',
#   'approach',
#   'deliv',
#   'real',
#   'bump-in',
#   '-',
#   'the-night',
#   'chill',
#   '--',
#   'greatest',
#   'triumph',
#   'keep',
#   'creepi',
#   'crawli',
#   'hidden',
#   'film',
#   'thick',
#   'shadow'],
#  ['movi',
#   'may',
#   'highest',
#   'product',
#   'valu',
#   'ever',
#   'seen',
#   'work',
#   'artist',
#   'one',
#   'whose',
#   'view',
#   'america',
#   'histori',
#   'awkward',
#   'human',
#   'life',
#   'generous',
#   'deep'],
#  ['feral', 'uncomfort'],
#  ['sillier',
#   'cuter',
#   'shorter',
#   'first',
#   '-lrb-',
#   'best',
#   'rememb',
#   '-rrb-',
#   'still',
#   'good',
#   'time',
#   'cinema'],
#  ['enjoy',
#   'expect',
#   'though',
#   'laugh',
#   'come',
#   'fair',
#   'basic',
#   'comed',
#   'construct'],
#  ['black-and-whit', 'unrealist'],
#  ['film',
#   'predict',
#   'reassur',
#   'manner',
#   'beauti',
#   'sung',
#   'holiday',
#   'carol'],
#  ['camouflag',
#   'carvey',
#   'consid',
#   'paper',
#   'bag',
#   'wear',
#   'head',
#   'goe',
#   'public',
#   'avoid',
#   'recogn',
#   'man',
#   'bilk',
#   'unsuspect',
#   'moviego'],
#  ['scare',
#   'mood',
#   'omin',
#   'pervas',
#   'unknown',
#   'threat',
#   'lurk',
#   'proceed',
#   'add',
#   'almost',
#   'constant',
#   'mindset',
#   'suspens'],
#  ['comput',
#   'anim',
#   'handsom',
#   'various',
#   'amus',
#   'sidekick',
#   'add',
#   'much-need',
#   'leviti',
#   'otherwis',
#   'bleak',
#   'tale',
#   'overal',
#   'film',
#   'never',
#   'rise',
#   'mediocr'],
#  ['offer',
#   'flash',
#   'rock',
#   'video',
#   'fuse',
#   'solid',
#   'perform',
#   'eeri',
#   'atmospher'],
#  ['breezi', 'blend', 'art', 'histori', 'esoter', 'muse', 'philosophi'],
#  ['former',
#   'gong',
#   'show',
#   'addict',
#   'admit',
#   'complaint',
#   'nt',
#   'get',
#   're-creat',
#   'famous',
#   'moment',
#   'show'],
#  ['genuin', 'unnerv'],
#  ['increas',
#   'divers',
#   'french',
#   'director',
#   'creat',
#   'film',
#   'one',
#   'honest',
#   'describ',
#   'look',
#   'sound',
#   'simpli',
#   'feel',
#   'like',
#   'film',
#   'recent',
#   'histori'],
#  ['one',
#   'joyous',
#   'film',
#   'leap',
#   'nation',
#   'boundari',
#   'celebr',
#   'univers',
#   'human',
#   'natur'],
#  ['difficult',
#   'worthi',
#   'film',
#   'bite',
#   'chew',
#   'link',
#   'massacr',
#   'armenian',
#   '1915',
#   'difficult',
#   'relationship',
#   'present'],
#  ['halfway', 'movi', 'humor', 'dwindl'],
#  ['witti',
#   'often',
#   'surpris',
#   'dark',
#   'littl',
#   'moral',
#   'tale',
#   'disguis',
#   'romant',
#   'comedi'],
#  ['one',
#   'sens',
#   'world',
#   'travel',
#   'earlier',
#   'film',
#   'freundlich',
#   'bear',
#   'grievous',
#   'obscur',
#   'complaint',
#   'father',
#   'circl',
#   'obsess',
#   'without',
#   'make',
#   'contact'],
#  ['fact', 'even', 'better'],
#  ['preachi', 'parabl', 'styliz', 'touch', 'john', 'woo', 'bullet', 'ballet'],
#  ['prove',
#   'movi',
#   'formula',
#   'nt',
#   'need',
#   'mess',
#   '--',
#   'like',
#   'big-bug',
#   'movi'],
#  ['uplift', 'larg', 'bogus', 'stori'],
#  ['thank',
#   'confid',
#   'filmmak',
#   'pair',
#   'fascin',
#   'perform',
#   'way',
#   'destin',
#   'realli',
#   'special',
#   'walk',
#   'wood'],
#  ['superbl',
#   'photograph',
#   'stage',
#   'mend',
#   'seri',
#   'rivet',
#   'set',
#   'piec',
#   'like',
#   'mainstream',
#   'audienc',
#   'rare',
#   'seen'],
#  ['mesmer', 'cinemat', 'poem', 'first', 'frame', 'last'],
#  ['first', '10', 'minut', 'worth', 'see'],
#  ['becom', 'appar', 'franchis', 'best', 'year', 'long', 'past'],
#  ['screenwrit',
#   'chris',
#   'ver',
#   'weil',
#   'direct',
#   'debut',
#   'good-natur',
#   'never',
#   'dull',
#   'virtu',
#   'small',
#   'easili',
#   'overshadow',
#   'predict'],
#  ['much',
#   'storytel',
#   'move',
#   'away',
#   'solondz',
#   'social',
#   'critiqu',
#   'cast',
#   'audienc',
#   'intellectu',
#   'lector',
#   'contempl',
#   'auteur',
#   'profession',
#   'injuri'],
#  ['ultim',
#   'sarah',
#   'dedic',
#   'find',
#   'husband',
#   'seem',
#   'psychot',
#   'romant',
#   'noth',
#   'movi',
#   'make',
#   'convinc',
#   'case',
#   'one',
#   'woman',
#   'broken',
#   'heart',
#   'outweigh',
#   'loss',
#   'wit'],
#  ['joke', 'flat', 'action', 'look', 'fake'],
#  ['mild', 'enjoy', 'toothless', 'adapt', 'much', 'better', 'book'],
#  ['fester', 'dungpil', 'swear', 'watch', 'monkey', 'fling', 'fece'],
#  ['addit',
#   'overcook',
#   'ham-fist',
#   'direct',
#   'actor',
#   'reach',
#   'back',
#   'row',
#   'dialogu',
#   'sound',
#   'like',
#   'horribl',
#   'poetri'],
#  ['vile',
#   'incoher',
#   'mess',
#   'scummi',
#   'ripoff',
#   'david',
#   'cronenberg',
#   'brilliant',
#   'videodrom'],
#  ['first', 'movi', 'tri', 'smart', 'kinda', 'dumb'],
#  ['sent', 'copyof', 'film', 'review', 'dvd'],
#  ['silli', 'humbuggeri'],
#  ['nt',
#   'sharp',
#   'origin',
#   'despit',
#   'visual',
#   'virtu',
#   'blade',
#   'ii',
#   'nt',
#   'cut'],
#  ['smart', 'arch', 'rather', 'cold-blood', 'comedi'],
#  ['-lrb-', '-rrb-', 'rather', 'thinly-conceiv', 'movi'],
#  ['flame-lik', 'roil', 'black-and-whit', 'inspir', 'trembl', 'gratitud'],
#  ['robinson',
#   'web',
#   'suspens',
#   'match',
#   'page-turn',
#   'frenzi',
#   'clanci',
#   'creat'],
#  ['slight', 'sweet', 'film'],
#  ['got', 'david', 'lynch', 'jone'],
#  ['earnest', 'tentat', 'even', 'aim', 'shock'],
#  ['time',
#   'favor',
#   'could',
#   'given',
#   'audienc',
#   'time',
#   'day',
#   'concentr',
#   'element',
#   'reveal',
#   'alien',
#   'among',
#   'cultur',
#   'peopl',
#   'sad',
#   'hostil',
#   'odd',
#   'one',
#   'anoth',
#   'reckless',
#   'retali'],
#  ['austin',
#   'power',
#   'goldmemb',
#   'right',
#   'stuff',
#   'silli',
#   'summer',
#   'entertain',
#   'enough',
#   'laugh',
#   'sustain',
#   'interest',
#   'end'],
#  ['puzzl', 'lack', 'emphasi', 'music', 'britney', 'spear', 'first', 'movi'],
#  ['filmmak', 'might', 'want', 'look'],
#  ['maintain',
#   'appear',
#   'clinic',
#   'object',
#   'sad',
#   'occasion',
#   'horrifi',
#   'often',
#   'inspir',
#   'film',
#   'among',
#   'wiseman',
#   'warmest'],
#  ['simpli',
#   'doubt',
#   'film',
#   'ask',
#   'right',
#   'question',
#   'right',
#   'time',
#   'histori',
#   'countri'],
#  ['dreari', 'movi'],
#  ['sad',
#   'though',
#   'mani',
#   'actor',
#   'throw',
#   'spark',
#   'two',
#   'first',
#   'appear',
#   'ca',
#   'nt',
#   'generat',
#   'enough',
#   'heat',
#   'cold',
#   'vacuum',
#   'comedi',
#   'start',
#   'reaction'],
#  ['filmmak',
#   'ivan',
#   'princ',
#   'fellow',
#   'come',
#   'across',
#   'shallow',
#   'glib',
#   'though',
#   'mean-spirit',
#   'indic',
#   'respons',
#   'put',
#   'togeth',
#   'movi',
#   'particular',
#   'valu',
#   'merit'],
#  ['use',
#   'stock',
#   'plot',
#   'boy',
#   'inject',
#   'enough',
#   'fresh',
#   'proceed',
#   'provid',
#   'enjoy',
#   '100',
#   'minut',
#   'movi',
#   'theater'],
#  ['beat',
#   'austin',
#   'power',
#   'film',
#   'game',
#   'blaxploit',
#   'spoof',
#   'downplay',
#   'raunch',
#   'favor',
#   'gag',
#   'reli',
#   'strength',
#   'clever',
#   'oppos',
#   'extent',
#   'outrag'],
#  ['begin',
#   'convent',
#   'thriller',
#   'evolv',
#   'gorgeous',
#   'atmospher',
#   'medit',
#   'life-chang',
#   'chanc',
#   'encount'],
#  ['buy', 'popcorn'],
#  ['late-night',
#   'cabl',
#   'sexploit',
#   'romp',
#   'masquerad',
#   'thriller',
#   'ruthless',
#   'social',
#   'order',
#   'govern',
#   'colleg',
#   'cliqu'],
#  ['well-intent',
#   'effort',
#   'still',
#   'burden',
#   'actor',
#   'offbeat',
#   'sensibl',
#   'earnest',
#   'emot',
#   'core',
#   'emerg',
#   'degre',
#   'access'],
#  ['-lrb-',
#   'allen',
#   '-rrb-',
#   'make',
#   'piffl',
#   'long',
#   'hollywood',
#   'end',
#   'may',
#   'way',
#   'say',
#   'piffl',
#   'airhead',
#   'movi',
#   'busi',
#   'deserv',
#   'right'],
#  ['see',
#   'film',
#   'lack',
#   'momentum',
#   'posit',
#   'remain',
#   'most',
#   'undetermin',
#   'director',
#   'experi',
#   'success',
#   'one'],
#  ['judith',
#   'zaza',
#   'extend',
#   'bedroom',
#   'sequenc',
#   'intim',
#   'sensual',
#   'funni',
#   'psycholog',
#   'self-rev',
#   'make',
#   'pass',
#   'sex',
#   'movi',
#   'look',
#   'like',
#   'cheap',
#   'hyster'],
#  ['uneven', 'perform', 'spotti', 'script', 'add', 'bite', 'satir', 'teeth'],
#  ['irrit', 'soul-search', 'garbag'],
#  ['solid', 'spooki', 'entertain', 'worthi', 'price', 'ticket'],
#  ['ultim', 'clariti', 'matter', 'break', 'code', 'make', 'movi'],
#  ['comparison',
#   'earlier',
#   'film',
#   'seem',
#   'disappoint',
#   'thin',
#   'slice',
#   'lower-class',
#   'london',
#   'life',
#   ';',
#   'despit',
#   'titl',
#   'amount',
#   'surpris',
#   'littl'],
#  ['prove',
#   'main',
#   'south',
#   'korean',
#   'filmmak',
#   'make',
#   'undemand',
#   'action',
#   'movi',
#   'alacr',
#   'hollywood',
#   'counterpart'],
#  ['except', 'much', 'much', 'better'],
#  ['happi',
#   'headi',
#   'jumbl',
#   'thought',
#   'storytel',
#   'insan',
#   'comic',
#   'undertak',
#   'ultim',
#   'coher',
#   'sane',
#   'breathtak',
#   'creativ',
#   'film'],
#  ['one', 'joke', 'put', 'toilet', 'seat'],
#  ['-rrb-'],
#  ['origin', 'base', 'concept', 'help', 'get', 'caught'],
#  ['appear',
#   'made',
#   'peopl',
#   'idea',
#   'narrat',
#   'logic',
#   'cohes',
#   'entir',
#   'foreign',
#   'concept'],
#  ['ignor',
#   'clich',
#   'concentr',
#   'citi',
#   'sea',
#   'interperson',
#   'drama',
#   'ai',
#   'nt',
#   'half-bad'],
#  ['dread',
#   'day',
#   'irish',
#   'histori',
#   'given',
#   'passion',
#   'somewhat',
#   'flaw',
#   'treatment'],
#  ['see'],
#  ['noth', 'episod', 'smackdown'],
#  ['guilti', 'pleasur', 'best', 'worth', 'see', 'unless', 'want', 'laugh'],
#  ['perhap',
#   'better',
#   'celebr',
#   'unfair',
#   'dismiss',
#   'hero',
#   'would',
#   'film',
#   'nt',
#   'pain',
#   'forc',
#   'fals',
#   'fabric'],
#  ['relat', 'letdown'],
#  ['hey', 'arnold'],
#  ['though',
#   'scratch',
#   'surfac',
#   'least',
#   'provid',
#   'strong',
#   'itch',
#   'explor'],
#  ['band',
#   'perform',
#   'featur',
#   'drumlin',
#   'red',
#   'hot',
#   '-lrb-',
#   '-rrb-',
#   'mere',
#   'stori',
#   'point',
#   'view',
#   'film',
#   'ice',
#   'cold'],
#  ['non-mysteri', 'mysteri'],
#  ['leigh',
#   'one',
#   'rare',
#   'director',
#   'feel',
#   'act',
#   'heart',
#   'soul',
#   'cinema'],
#  ['cast', 'deliv', 'without', 'sham', 'raw-nerv', 'stori'],
#  ['monument',
#   'achiev',
#   'practic',
#   'everi',
#   'facet',
#   'inept',
#   'filmmak',
#   ':',
#   'joyless',
#   'idiot',
#   'annoy',
#   'heavy-hand',
#   'visual',
#   'atroci',
#   'often',
#   'downright',
#   'creepi'],
#  ['filmmak', 'heart', 'right', 'place'],
#  ['one', 'highly-prais', 'disappoint', 'misfortun', 'watch', 'quit', 'time'],
#  ['rock', 'stand-up', 'magic', 'wane'],
#  ['roman',
#   'polanski',
#   'direct',
#   'pianist',
#   'like',
#   'surgeon',
#   'mend',
#   'broken',
#   'heart',
#   ';',
#   'meticul',
#   'without',
#   'passion'],
#  ['sad', 'garth', 'nt', 'progress', 'nice', 'wayn'],
#  ['wit',
#   'empathi',
#   'spare',
#   'waydowntown',
#   'acknowledg',
#   'silent',
#   'scream',
#   'workaday',
#   'inertia',
#   'stop',
#   'short',
#   'indulg',
#   'charact',
#   'strive',
#   'solips'],
#  ['labour', 'storytel'],
#  ['rememb', 'back', 'thriller', 'actual', 'thrill'],
#  ['otherwis',
#   'good-natured',
#   'mr',
#   'deed',
#   'embrac',
#   'sheer',
#   'goofi',
#   'cameo',
#   'less',
#   '-',
#   'than-lik',
#   'new',
#   'york',
#   'celebr',
#   'certain',
#   'rais',
#   'film',
#   'anyth',
#   'sandler',
#   'attach'],
#  ['fail',
#   'fundament',
#   'everi',
#   'convent',
#   'level',
#   'achiev',
#   'kind',
#   'goofi',
#   'grandeur'],
#  ['ho-hum', 'affair', 'alway', 'watchabl', 'yet', 'hard', 'memor'],
#  ['saw', 'movi', 'well', 'probabl', 'accur', 'call', 'movi'],
#  ['though',
#   'uniform',
#   'well',
#   'act',
#   'especi',
#   'young',
#   'ballesta',
#   'galan',
#   '-lrb-',
#   'first-tim',
#   'actor',
#   '-rrb-',
#   'writer\\',
#   'director',
#   'achero',
#   'mana',
#   'film',
#   'schemat',
#   'obvious'],
#  ['resurrect', 'dead', 'man', 'hard', 'copi', 'come', 'a-knock'],
#  ['idea',
#   'white',
#   'man',
#   'arriv',
#   'foreign',
#   'shore',
#   'show',
#   'wari',
#   'nativ',
#   'true',
#   'light',
#   'abhorr',
#   'simplist',
#   'heaven',
#   'quit',
#   'like',
#   'like',
#   'hell'],
#  ['hard',
#   'believ',
#   'relationship',
#   'like',
#   'holli',
#   'marina',
#   'could',
#   'surviv',
#   'hothous',
#   'emot',
#   'teendom',
#   'longev',
#   'get',
#   'inexplic',
#   'character',
#   'turn',
#   'crassli',
#   'reduct'],
#  ['movi',
#   'audienc',
#   'hour',
#   'nt',
#   'connect',
#   'neat',
#   'way',
#   'introduc',
#   'charact',
#   'illumin',
#   'mysteri',
#   'sex',
#   'duti',
#   'love'],
#  ['purport',
#   'hollywood',
#   'satir',
#   'wind',
#   'kind',
#   'film',
#   'target',
#   'someth',
#   'deeper',
#   'engag'],
#  ['clever', 'nine-tenth'],
#  ['waterboy'],
#  ['go', 'motion', 'zip', 'gone'],
#  ['script',
#   'snazzi',
#   'dialogu',
#   'establish',
#   'realist',
#   'atmospher',
#   'involv',
#   'us',
#   'unfold',
#   'crisi',
#   'lazi',
#   'plot',
#   'ensur',
#   'littl',
#   'emot',
#   'invest',
#   'pay'],
#  ['good', 'origin'],
#  ['moviego',
#   'would',
#   'automat',
#   'bypass',
#   'hip-hop',
#   'documentari',
#   'give',
#   'scratch',
#   'second',
#   'look'],
#  ['bigelow',
#   'offer',
#   'flashi',
#   'twist',
#   'turn',
#   'occasion',
#   'fortifi',
#   'turgid',
#   'fabl'],
#  ['unsophist', 'sci-fi', 'drama', 'take', 'serious'],
#  ['stupid', 'infantil', 'redund', 'sloppi', 'over-the-top', 'amateurish'],
#  ['resid',
#   'evil',
#   'come',
#   'take',
#   'john',
#   'carpent',
#   'ghost',
#   'mar',
#   'elimin',
#   'behead'],
#  ['movi',
#   'resolut',
#   'avoid',
#   'comic',
#   'possibl',
#   'situat',
#   'becom',
#   'one',
#   'dumb',
#   'high',
#   'school',
#   'comedi',
#   'sex',
#   'gag',
#   'prom',
#   'date'],
#  ['without',
#   'sex',
#   'wonder',
#   'tale',
#   'love',
#   'destini',
#   'told',
#   'well',
#   'master',
#   'storytel'],
#  ['though',
#   'goe',
#   'anyon',
#   'seen',
#   'hunger',
#   'cat',
#   'peopl',
#   'find',
#   'littl',
#   'new',
#   'tasti',
#   'perform',
#   'vincent',
#   'gallo',
#   'lift',
#   'tale',
#   'cannib',
#   'lust',
#   'ordinari'],
#  ['terrif', 'date', 'movi', 'whatev', 'orient'],
#  ['expect',
#   'laughter',
#   'quash',
#   'whatev',
#   'obscen',
#   'hand',
#   'even',
#   'funniest',
#   'idea',
#   'nt',
#   'funni'],
#  ['make', 'movi', 'depth', 'man', 'lack'],
#  ['translat', ':', 'nt', 'need', 'tri', 'hard'],
#  ['frailti',
#   'offer',
#   'chill',
#   'much',
#   'like',
#   'get',
#   'sit',
#   'around',
#   'campfir',
#   'around',
#   'midnight',
#   'tell',
#   'creepi',
#   'stori',
#   'give',
#   'willi'],
#  ['less', 'front-load', 'shape', 'two-hour', 'version', 'releas', '1990'],
#  ['ambiti',
#   'movi',
#   'like',
#   'shiner',
#   'organ',
#   'big',
#   'fight',
#   'pull',
#   'enough',
#   'effect',
#   'make',
#   'one',
#   'nt',
#   'come'],
#  ['movi', 'suck', 'despit', 'flaw', 'heaven', 'one', 'beast'],
#  ['well', 'written', 'direct', 'brutal', 'honesti', 'respect', 'audienc'],
#  ['twenti',
#   'year',
#   'first',
#   'releas',
#   'e',
#   'remain',
#   'wondrous',
#   'hollywood',
#   'fantasi',
#   '--',
#   'apex',
#   'steven',
#   'spielberg',
#   'misunderstood',
#   'career'],
#  ['good', 'offer', 'desper', 'ingrati', 'perform'],
#  ['stumbl',
#   'everi',
#   'cheap',
#   'trick',
#   'book',
#   'tri',
#   'make',
#   'outrag',
#   'come',
#   'even',
#   'easier'],
#  ['nice',
#   'combin',
#   'enigmat',
#   'featur',
#   'memento',
#   'hallucinatori',
#   'drug',
#   'cultur',
#   'requiem',
#   'dream'],
#  ['everi',
#   'individu',
#   'see',
#   'movi',
#   'prism',
#   'belief',
#   'prejudic',
#   'one',
#   'thing',
#   'take',
#   'away',
#   'sens',
#   'peac',
#   'possibl'],
#  ['bunch',
#   'good',
#   'actor',
#   'flail',
#   'around',
#   'caper',
#   'neither',
#   'origin',
#   'terribl',
#   'funni'],
#  ['ill-conceiv',
#   'expens',
#   'project',
#   'wind',
#   'look',
#   'like',
#   'bunch',
#   'talent',
#   'thesp',
#   'slum'],
#  ['broder',
#   'screenplay',
#   'shallow',
#   'offens',
#   'redund',
#   'piti',
#   'real',
#   'laugh'],
#  ['leguizamo', 'jone', 'excel', 'rest', 'cast', 'uniform', 'superb'],
#  ['tri',
#   'figur',
#   'rule',
#   'countri',
#   'bear',
#   'univers',
#   '--',
#   'bear',
#   'bear',
#   'like',
#   'human',
#   'hairier',
#   '--',
#   'would',
#   'tax',
#   'einstein',
#   'brain'],
#  ['feardotcom',
#   'make',
#   'interest',
#   'medit',
#   'ether',
#   'natur',
#   'internet',
#   'otherworld',
#   'energi',
#   'could',
#   'channel',
#   'simpli',
#   'becom',
#   'routin',
#   'shocker'],
#  ['delia',
#   'greta',
#   'paula',
#   'rank',
#   'three',
#   'multilay',
#   'sympathet',
#   'femal',
#   'charact',
#   'year'],
#  ['beauti', 'alexand', 'payn', 'ode', 'everyman', 'detail'],
#  ['town',
#   'kind',
#   'authent',
#   'feel',
#   'one',
#   'peopl',
#   'stand',
#   'everybodi',
#   'els',
#   'background',
#   'seem',
#   'manufactur',
#   'artifici'],
#  ['juli',
#   'davi',
#   'kathi',
#   'lee',
#   'gifford',
#   'film',
#   'director',
#   'sad',
#   'prove',
#   'ego',
#   'nt',
#   'alway',
#   'go',
#   'hand',
#   'hand',
#   'talent'],
#  ['much',
#   'credit',
#   'must',
#   'given',
#   'water-camera',
#   'oper',
#   'team',
#   'king',
#   'sonni',
#   'miller',
#   'michael',
#   'stewart'],
#  ['film',
#   'aussi',
#   'david',
#   'caesar',
#   'channel',
#   'not-quite-dead',
#   'career',
#   'guy',
#   'ritchi'],
#  ['avers',
#   'usual',
#   'feel-good',
#   'follow-your-dream',
#   'hollywood',
#   'fantasi',
#   'one',
#   'got'],
#  ['mayb', 'formula', 'filmmak', 'noth', 'wrong', 'film', 'well-craft', 'one'],
#  ['would', 'laugh', 'tuba-play', 'dwarf', 'roll', 'hill', 'trash'],
#  ['lose',
#   'sens',
#   'humor',
#   'vat',
#   'fail',
#   'joke',
#   'twitchi',
#   'act',
#   'general',
#   'boorish'],
#  ['misty-ey',
#   'southern',
#   'nostalgia',
#   'piec',
#   'tread',
#   'line',
#   'sappi',
#   'sanguin',
#   'wind',
#   'mire',
#   'tear-drench',
#   'quicksand'],
#  ['oblivi', 'exist', 'film', 'would', 'sweet', 'inde'],
#  ['despit',
#   'flaw',
#   'belinski',
#   'still',
#   'abl',
#   'creat',
#   'engag',
#   'stori',
#   'keep',
#   'guess',
#   'almost',
#   'everi',
#   'turn'],
#  ['porn', 'film', 'without', 'sex', 'scene'],
#  ['movi',
#   'play',
#   'cartoon',
#   'obvious',
#   'strength',
#   'snazzi',
#   'neglect',
#   'less',
#   'conspicu',
#   'write',
#   'strength'],
#  ['notwithstand',
#   'problem',
#   'movi',
#   'final',
#   'half',
#   'hour',
#   'go',
#   'recommend',
#   'secretari',
#   'base',
#   'wonder',
#   'act',
#   'clinic',
#   'put',
#   'spader',
#   'gyllenha',
#   'also',
#   'uniqu',
#   'way',
#   'shainberg',
#   'goe',
#   'tell',
#   'heart',
#   'sweet',
#   'littl',
#   'girl',
#   '-'],
#  ['despit',
#   'slick',
#   'product',
#   'valu',
#   'director',
#   'roger',
#   'michel',
#   'tick-tock',
#   'pace',
#   'final',
#   'effect',
#   'like',
#   'two',
#   'guy',
#   'yell',
#   'face',
#   'two',
#   'hour'],
#  ['barbershop',
#   'good-heart',
#   'ensembl',
#   'comedi',
#   'varieti',
#   'quirki',
#   'charact',
#   'engag',
#   'stori'],
#  ['soulless',
#   'jumbl',
#   'inept',
#   'assembl',
#   'clich',
#   'pabulum',
#   'play',
#   'like',
#   '95-minut',
#   'commerci',
#   'nba',
#   'properti'],
#  ['ambiti',
#   'serious',
#   'film',
#   'manag',
#   'virtual',
#   'everyth',
#   'wrong',
#   ';',
#   'sit',
#   'someth',
#   'akin',
#   'act',
#   'cinemat',
#   'penanc'],
#  ['consist', 'clever', 'suspens'],
#  ['soderbergh', 'skim', 'fat', '1972', 'film'],
#  ['hilari', 'music', 'comedi', 'though', 'stymi', 'accent', 'thick', 'mud'],
#  ['movi', 'like', 'guy', 'film', 'critic', 'consid', 'work'],
#  ['anyon',
#   'suffer',
#   'film',
#   'deserv',
#   'least',
#   'big',
#   'box',
#   'consol',
#   'candi'],
#  ['bearabl'],
#  ['cremast',
#   '3',
#   'tough',
#   'pill',
#   'swallow',
#   'minor',
#   'miracl',
#   'self-express'],
#  ['kouyat',
#   'elicit',
#   'strong',
#   'perform',
#   'cast',
#   'deliv',
#   'power',
#   'commentari',
#   'govern',
#   'lie',
#   'matter',
#   'run'],
#  ['see', 'perform', 'noth', 'els'],
#  ['asylum', 'materi', 'grip', 'scene', 'jia', 'famili'],
#  ['walk',
#   'away',
#   'new',
#   'version',
#   'e',
#   'hope',
#   'would',
#   '--',
#   'moist',
#   'eye'],
#  ['attal', 'push', 'hard', 'make', 'comedi', 'serious', 'drama'],
#  ['play', 'like', 'corni', 'televis', 'product', 'bygon', 'era'],
#  ['power',
#   'though',
#   'flaw',
#   'movi',
#   'guarante',
#   'put',
#   'lump',
#   'throat',
#   'reaffirm',
#   'washington',
#   'possibl',
#   'best',
#   'actor',
#   'work',
#   'movi',
#   'today'],
#  ['solondz', 'may', 'well', 'one', 'laugh', 'joke'],
#  ['case',
#   'two',
#   'actor',
#   'everyth',
#   'human',
#   'possibl',
#   'creat',
#   'charact',
#   'sweet',
#   'believ',
#   'defeat',
#   'screenplay',
#   'forc',
#   'bizarr',
#   'implaus',
#   'behavior'],
#  ['enjoy',
#   'hing',
#   'person',
#   'threshold',
#   'watch',
#   'sad',
#   'endear',
#   'charact',
#   'extrem',
#   'unconvent',
#   'thing'],
#  ['bodi', 'smack', 'exhibition', 'cathart', 'truth', 'tell'],
#  ['though',
#   'writer\\',
#   'director',
#   'bart',
#   'freundlich',
#   'film',
#   'ultim',
#   'becom',
#   'simplist',
#   'stori',
#   'dysfunct',
#   'parent-child',
#   'relationship',
#   'special',
#   'qualiti',
#   'soul',
#   'graviti',
#   'crudup',
#   'anchor',
#   'perform'],
#  ['-lrb-',
#   'carvey',
#   '-rrb-',
#   'charact',
#   'overplay',
#   'exagger',
#   'subtleti',
#   'never',
#   'trademark'],
#  ['beauti', 'anim', 'epic', 'never', 'dull'],
#  ['charm', 'witti', 'also', 'somewhat', 'clumsi'],
#  ['one',
#   'scene',
#   'get',
#   'stab',
#   'soccer',
#   'hooligan',
#   'double-barrel',
#   'rip-off',
#   'quentin',
#   'tarantino',
#   'climact',
#   'shootout',
#   '--',
#   'meat',
#   'loaf',
#   'explod'],
#  ['frustrat', 'refus', 'give', 'pinochet', 'crime', 'polit', 'context'],
#  ['paul', 'bettani', 'play', 'malcolm', 'mcdowel'],
#  ['servic',
#   'euro-trash',
#   'action',
#   'extravaganza',
#   'decent',
#   'sens',
#   'humor',
#   'plenti',
#   'thing',
#   'go',
#   'boom',
#   '--',
#   'handgun',
#   'bmws',
#   'seasid',
#   'chateaus'],
#  ['veteran',
#   'date',
#   'war',
#   'smirk',
#   'uneasili',
#   'film',
#   'nightmar',
#   'version',
#   'everyday',
#   'sex-in-the-c',
#   'misadventur'],
#  ['send', 'away', 'believ', 'quit', 'cheer'],
#  ['rollerbal', 'sequenc', 'feel', 'sanitis', 'stagey'],
#  ['interview',
#   'assassin',
#   'structur',
#   'less',
#   'documentari',
#   'found',
#   'relic',
#   'film',
#   'difficult',
#   'time',
#   'shake',
#   'blair',
#   'witch',
#   'project',
#   'real-tim',
#   'root'],
#  ['remark',
#   'epic',
#   'scope',
#   'startl',
#   'intimaci',
#   'achiev',
#   'despit',
#   'breadth'],
#  ['near', '21\\', '2', 'hour', 'film', 'way', 'indulg'],
#  ['seem',
#   'like',
#   'someth',
#   'american',
#   'european',
#   'gay',
#   'movi',
#   '20',
#   'year',
#   'ago'],
# ...
#  ['definit', 'crowd-pleas', 'roman', 'colosseum'],
#  ['vh1',
#   'behind',
#   'music',
#   'special',
#   'someth',
#   'littl',
#   'special',
#   'behind',
#   ':',
#   'music',
#   'nt',
#   'sell',
#   'mani',
#   'record',
#   'help',
#   'chang',
#   'nation'],
#  ['kid',
#   'love',
#   'fantasi',
#   'adventur',
#   'grownup',
#   'appreci',
#   'whimsic',
#   'humor'],
#  ['took',
#   'three',
#   'minut',
#   'dialogu',
#   '30',
#   'second',
#   'plot',
#   'turn',
#   '90-minut',
#   'movi',
#   'feel',
#   'five',
#   'hour',
#   'long'],
#  ['intermin', 'bleak', 'say', 'noth', 'bore'],
#  ['natur',
#   'funni',
#   'film',
#   'home',
#   'movi',
#   'make',
#   'crave',
#   'chris',
#   'smith',
#   'next',
#   'movi'],
#  ['bai',
#   'brother',
#   'taken',
#   'small',
#   'slice',
#   'histori',
#   'open',
#   'us',
#   'understand',
#   'told',
#   'nice',
#   'littl',
#   'stori',
#   'process'],
#  ['meatbal', 'bare-midriff', 'generat'],
#  ['movi', 'worst', 'thing', 'chan', 'done', 'unit', 'state'],
#  ['maintain', 'interest', 'end', 'even', 'leav', 'linger', 'anim', 'thought'],
#  ['blush',
#   'gush',
#   '--',
#   'imamura',
#   'squirt',
#   'screen',
#   'warm',
#   'water',
#   'red',
#   'bridg'],
#  ['entertain', 'dispos', 'hanna-barbera', 'half-hour', 'cartoon', 'ever'],
#  ['beauti',
#   'imag',
#   'solemn',
#   'word',
#   'disguis',
#   'slack',
#   'complac',
#   '-lrb-',
#   'godard',
#   '-rrb-',
#   'vision',
#   'gorgeous',
#   'piano',
#   'string',
#   'soundtrack',
#   'drown',
#   'tinni',
#   'self-right',
#   'voic'],
#  ['dylan',
#   'thoma',
#   'aliv',
#   'wit',
#   'first-tim',
#   'director',
#   'ethan',
#   'hawk',
#   'strain',
#   'chelsea',
#   'wall',
#   'might',
#   'tempt',
#   'chang',
#   'landmark',
#   'poem',
#   'go',
#   'gentl',
#   'good',
#   'theatr'],
#  ['affirm',
#   'gift',
#   'involv',
#   'start',
#   'spielberg',
#   'go',
#   'right',
#   'rank',
#   'player',
#   '--',
#   'on-camera',
#   '--',
#   'bring',
#   'togeth'],
#  ['somewhat', 'disappoint', 'meander', 'saga'],
#  ['action', 'scene', 'thing', 'fall', 'apart'],
#  ['palpabl',
#   'chemistri',
#   'lopez',
#   'male',
#   'lead',
#   'ralph',
#   'fienn',
#   'plus',
#   'script',
#   'work',
#   'girl',
#   'scribe',
#   'kevin',
#   'wade',
#   'workmanlik',
#   'extrem'],
#  ['clever', 'craft', 'ultim', 'hollow', 'mockumentari'],
#  ['uneven', 'movi', 'charm', 'funni', 'moment', 'quit', 'enough'],
#  ['unintent',
#   'surreal',
#   'kid',
#   'pictur',
#   'actor',
#   'bad',
#   'bear',
#   'suit',
#   'enact',
#   'sort',
#   'inter-speci',
#   'parodi',
#   'vh1',
#   'behind',
#   'music',
#   'episod'],
#  ['break', 'heart', 'mani', 'time'],
#  ['lax', 'limp', 'comedi', 'seen', 'meander', 'worn-out', 'materi'],
#  ['sitcomish', 'predict', 'cloy', 'attempt', 'poignant'],
#  ['though',
#   'rude',
#   'crude',
#   'film',
#   'deliv',
#   'gut-bust',
#   'laugh',
#   'dig',
#   'modern',
#   'societi',
#   'thing',
#   'seen'],
#  ['-lrb-', '-rrb-', 'mess'],
#  ['work', 'lack', 'purpos', 'strong', 'puls'],
#  ['sword', 'fight', 'well', 'done', 'auteuil', 'goofi', 'pleasur'],
#  ['stereotyp'],
#  ['imax', 'screen', 'enhanc', 'person', 'touch', 'manual', 'anim'],
#  ['kaufman',
#   'jonz',
#   'take',
#   'huge',
#   'risk',
#   'ponder',
#   'whole',
#   'notion',
#   'passion',
#   '--',
#   'desir',
#   'human',
#   'be',
#   'passion',
#   'live',
#   'empti',
#   'one',
#   'feel',
#   'miss'],
#  ['god',
#   'bless',
#   'crudup',
#   'avers',
#   'take',
#   'easi',
#   'hollywood',
#   'road',
#   'cash',
#   'movie-star',
#   'gorgeous'],
#  ['comedi'],
#  ['unlik',
#   'surf',
#   'movi',
#   'blue',
#   'crush',
#   'thrill',
#   'use',
#   'modern',
#   'technolog',
#   'take',
#   'viewer',
#   'insid',
#   'wave'],
#  ['best', 'part', 'gang', 'daniel', 'day-lewi'],
#  ['wait', 'godard', 'fruit', ':', 'prais', 'love', 'director', 'epitaph'],
#  ['edgi', 'thriller', 'deliv', 'surpris', 'punch'],
#  ['movi',
#   'would',
#   'seem',
#   'less',
#   'trifl',
#   'ms',
#   'sugarman',
#   'follow',
#   'defianc',
#   'saccharin'],
#  ['war', 'rose', 'trailer-trash', 'style'],
#  ['result', 'power', 'natur', 'dramat', 'piec', 'low-budget', 'filmmak'],
#  ['fifti', 'car', 'pileup', 'clich'],
#  ['whole',
#   'stretch',
#   'film',
#   'may',
#   'incomprehens',
#   'moviego',
#   'alreadi',
#   'clad',
#   'basic',
#   'black'],
#  ['piti', 'slapdash', 'disast'],
#  ['charlott', 'sometim', 'brilliant', 'movi'],
#  ['end', 'simpli', 'admir', 'bit', 'perform'],
#  ['godard',
#   'never',
#   'made',
#   'sheer',
#   'beauti',
#   'film',
#   'unexpect',
#   'move',
#   'medit',
#   'love',
#   'histori',
#   'memori',
#   'resist',
#   'artist',
#   'transcend'],
#  ['erot', 'thriller', 'neither', 'erot', 'thrill', 'either'],
#  ['carri',
#   'spot-on',
#   'scottish',
#   'burr',
#   'duval',
#   '-lrb-',
#   'also',
#   'produc',
#   '-rrb-',
#   'peel',
#   'layer',
#   'charact',
#   'may',
#   'well',
#   'exist',
#   'paper'],
#  ['solid',
#   'piec',
#   'journalist',
#   'work',
#   'draw',
#   'pictur',
#   'man',
#   'polit',
#   'expedi',
#   'becam',
#   'dead',
#   'foreign',
#   'polici'],
#  ['hopkin', 'squar', 'fill', 'screen'],
#  ['irwin',
#   'director',
#   'never',
#   'come',
#   'adequ',
#   'reason',
#   'pay',
#   'money',
#   'get',
#   'televis',
#   'free'],
#  ['everyth',
#   'titl',
#   'impli',
#   'standard-issu',
#   'crime',
#   'drama',
#   'spat',
#   'tinseltown',
#   'assembl',
#   'line'],
#  ['unfold',
#   'one',
#   'polit',
#   'audaci',
#   'film',
#   'recent',
#   'decad',
#   'countri',
#   'especi',
#   'franc'],
#  ['abandon', 'leav', 'want', 'abandon', 'theater'],
#  ['probabl', 'best', 'case', 'christian', 'sinc', 'chesterton', 'lewi'],
#  ['long', 'desper', 'even', 'end'],
#  ['rather', 'shapeless', 'good', 'time'],
#  ['feel',
#   'like',
#   'reject',
#   'x-file',
#   'episod',
#   'credibl',
#   'account',
#   'puzzl',
#   'real-lif',
#   'happen'],
#  ['amount', 'good', 'intent', 'abl', 'overcom', 'trivial', 'stori'],
#  ['-lrb-',
#   'ramsay',
#   '-rrb-',
#   'visual',
#   'transform',
#   'dreari',
#   'expans',
#   'dead-end',
#   'distast',
#   'charact',
#   'inhabit',
#   'poem',
#   'art',
#   'music',
#   'metaphor'],
#  ['film', '-lrb-', '-rrb-', 'moment', 'far'],
#  ['sweet',
#   'affect',
#   'stori',
#   'four',
#   'sister',
#   'cope',
#   'one',
#   'way',
#   'anoth',
#   'life',
#   'endgam'],
#  ['disturb', 'examin', 'appear', 'definit', 'bad', 'polic', 'shoot'],
#  ['distanc',
#   'throw',
#   'mani',
#   'red',
#   'herring',
#   'mani',
#   'fals',
#   'scare',
#   'genuin',
#   'one',
#   'bare',
#   'regist'],
#  ['almost'],
#  ['everi', 'sequel', 'skip', 'two', 'hour', 'gain'],
#  ['done'],
#  ['exist', 'hush', 'line', 'like', 'back'],
#  ['somehow',
#   'ms',
#   'griffith',
#   'mr',
#   'pryce',
#   'bring',
#   'wild',
#   'welsh',
#   'whimsi'],
#  ['densest', 'distil', 'robert', 'movi', 'ever', 'made'],
#  ['lot',
#   'effort',
#   'intellig',
#   'display',
#   'execut',
#   'awkward',
#   'static',
#   'lifeless',
#   'rumbl'],
#  ['one', 'outstand', 'thriller', 'recent', 'year'],
#  ['consid',
#   'film',
#   'celluloid',
#   'litmus',
#   'test',
#   'intellectu',
#   'emot',
#   'pedigre',
#   'date',
#   'giant',
#   'step',
#   'backward',
#   'director',
#   'admir'],
#  ['subtitl',
#   'costum',
#   'drama',
#   'set',
#   'remot',
#   'african',
#   'empir',
#   'cell',
#   'phone',
#   'gun',
#   'intern',
#   'combust',
#   'engin',
#   'polit',
#   'thump',
#   'time',
#   'tomorrow'],
#  ['open',
#   'contriv',
#   'banter',
#   'clich',
#   'loos',
#   'end',
#   'screenplay',
#   'come',
#   'second',
#   'half'],
#  ['captiv', 'new', 'film'],
#  ['ador',
#   'full',
#   'monti',
#   'resound',
#   'die',
#   'see',
#   'old',
#   'thing',
#   'tire',
#   'old',
#   'set',
#   'keep',
#   'reason',
#   'entertain'],
#  ['worth', 'catch', 'griffith', 'warm', 'win', 'central', 'perform'],
#  ['sorvino',
#   'make',
#   'princess',
#   'seem',
#   'smug',
#   'cartoonish',
#   'film',
#   'realli',
#   'come',
#   'aliv',
#   'poor',
#   'hermocr',
#   'leontin',
#   'pathet',
#   'compar',
#   'note',
#   'bud',
#   'amour'],
#  ['make',
#   'melodrama',
#   'filmmak',
#   'cut',
#   'natur',
#   'grain',
#   'produc',
#   'work',
#   'interest',
#   'ask',
#   'question',
#   'answer'],
#  ['davi', 'funni', 'charm', 'quirki', 'featur', 'film', 'act', 'debut', 'ami'],
#  ['uncomfort',
#   'movi',
#   'suffoc',
#   'sometim',
#   'almost',
#   'senseless',
#   'grey',
#   'zone',
#   'center',
#   'though',
#   'morbid',
#   'one'],
#  ['lousi',
#   'john',
#   'q',
#   'spit',
#   'denzel',
#   'washington',
#   'fine',
#   'perform',
#   'titl',
#   'role'],
#  ['devoid', 'pleasur', 'sensual', 'even', 'dub', 'hedonist'],
#  ['satin',
#   'roug',
#   'new',
#   'invent',
#   'journey',
#   'encourag',
#   'see',
#   'three-dimension',
#   'averag',
#   'middle-ag',
#   'woman',
#   'experi',
#   'self-discoveri',
#   'handl',
#   'sensit'],
#  ['point',
#   'often',
#   'tender',
#   'examin',
#   'pros',
#   'con',
#   'uncondit',
#   'love',
#   'famili',
#   'duti'],
#  ['anoth', 'trumpet', 'blast', 'may', 'new', 'mexican', 'cinema', 'a-bornin'],
#  ['gorgeous',
#   'look',
#   'insuffer',
#   'tedious',
#   'turgid',
#   'curious',
#   'constrict',
#   'epic'],
#  ['sexi',
#   'danger',
#   'actress',
#   'role',
#   'remind',
#   'everi',
#   'turn',
#   'elizabeth',
#   'berkley',
#   'flop',
#   'dolphin-gasm'],
#  ['contrast', 'neither', 'dramat', 'comic', '--', 'weird', 'fizzl'],
#  ['collater', 'damag', 'trash', 'earn', 'extra', 'point', 'act', 'nt'],
#  ['think',
#   'figur',
#   'bielinski',
#   'great',
#   'game',
#   'troubl',
#   ':',
#   'con',
#   'mark'],
#  ['swim',
#   'young',
#   'woman',
#   'face',
#   'cast',
#   'actress',
#   'whose',
#   'face',
#   'project',
#   'woman',
#   'doubt',
#   'yearn',
#   'succeed'],
#  ['pack', 'burst', 'incid', 'score', 'charact', 'fiction', 'histori'],
#  ['want', 'call', 'domino'],
#  ['umpteenth',
#   'summer',
#   'skinni',
#   'dip',
#   'jerri',
#   'bruckheim',
#   'putrid',
#   'pond',
#   'retread',
#   'action',
#   'twaddl'],
#  ['road', 'pave', 'good', 'intent', 'lead', 'video', 'store'],
#  ['chris',
#   'columbus',
#   'sequel',
#   'faster',
#   'liveli',
#   'good',
#   'deal',
#   'funnier',
#   'origin'],
#  ['full', 'flatul', 'joke', 'mild', 'sexual', 'refer', 'kung', 'pow'],
#  ['whole', 'affair', 'predict'],
#  ['film', 'good', 'view', 'altern', 'young', 'women'],
#  ['read',
#   'book',
#   'film',
#   'much',
#   'better',
#   'mother-daught',
#   'tale',
#   'last',
#   'summer',
#   'divin',
#   'secret',
#   'ya-ya',
#   'sisterhood',
#   'say',
#   'much'],
#  ['also', 'mani', 'thing', 'made', 'first', 'one', 'charm'],
#  ['sheridan'],
#  ['slight',
#   'premis',
#   'work',
#   'ideal',
#   'cast',
#   'master',
#   'british',
#   'actor',
#   'ian',
#   'holm',
#   'age',
#   'napoleon'],
#  ['never', 'mind', ';', 'boob', 'fantasti'],
#  ['schmidt', 'nicholson', 'goofi', 'heartfelt', 'mesmer', 'king', 'lear'],
#  ['thing',
#   'costner',
#   'movi',
#   'known',
#   ';',
#   'sanctimoni',
#   'self-right',
#   'eager',
#   'earn',
#   'love',
#   'want',
#   'slap'],
#  ['funni', 'heartwarm', 'film'],
#  ['piec',
#   'handiwork',
#   'show',
#   'indi',
#   'tatter',
#   'self-consci',
#   'seam',
#   'place',
#   'quiet',
#   'move',
#   'moment',
#   'intellig',
#   'subtleti'],
#  ['amus',
#   'entertain',
#   'unfold',
#   'bielinski',
#   'clever',
#   'construct',
#   'scenario',
#   'great',
#   'impress',
#   'skill',
#   'actor',
#   'involv',
#   'enterpris'],
#  ['distanc',
#   'pictur',
#   'provid',
#   'satisfi',
#   'unsettl',
#   'ride',
#   'dark',
#   'place',
#   'nation',
#   'psych'],
#  ['littl',
#   'add',
#   'beyond',
#   'dark',
#   'vision',
#   'alreadi',
#   'relay',
#   'superb',
#   'recent',
#   'predecessor',
#   'like',
#   'swim',
#   'shark',
#   'player',
#   'latest',
#   'skewer',
#   'may',
#   'put',
#   'insid',
#   'outsid',
#   'alik'],
#  ['uniqu',
#   'nt',
#   'necessarili',
#   'equat',
#   'good',
#   'matter',
#   'admir',
#   'filmmak',
#   'gone',
#   'broke'],
#  ['respect',
#   'charm',
#   'sandra',
#   'bullock',
#   'hugh',
#   'grant',
#   'worn',
#   'threadbar'],
#  ['like',
#   'hank',
#   'charact',
#   'slow',
#   'studi',
#   ':',
#   'action',
#   'stilt',
#   'tabloid',
#   'energi',
#   'embalm'],
#  ['enthusiast',
#   'invok',
#   'percuss',
#   'rhythm',
#   'brass',
#   'soul',
#   'sens',
#   'fierc',
#   'competit',
#   'help',
#   'make',
#   'great',
#   'march',
#   'band',
#   'half',
#   'fun',
#   'colleg',
#   'footbal',
#   'game'],
#  ['invigor', 'nt', 'give', 'damn'],
#  ['cacoyanni',
#   'perhap',
#   'effect',
#   'creat',
#   'atmospher',
#   'dust-cak',
#   'stagnat',
#   'labor',
#   'gentil'],
#  ['entertain', 'ultim', 'minor', 'thriller'],
#  ['real',
#   'star',
#   'movi',
#   'score',
#   'song',
#   'translat',
#   'well',
#   'film',
#   'realli',
#   'well',
#   'direct'],
#  ['punit', 'affirm', 'parabl'],
#  ['demm',
#   'final',
#   'succeed',
#   'diminish',
#   'statur',
#   'oscar-win',
#   'master',
#   'lowli',
#   'studio',
#   'hack'],
#  ['horrid',
#   'littl',
#   'propaganda',
#   'film',
#   'fascin',
#   'connect',
#   'serb',
#   'also',
#   'network',
#   'american',
#   'right-w',
#   'extremist'],
#  ['star\\',
#   'produc',
#   'salma',
#   'hayek',
#   'director',
#   'juli',
#   'taymor',
#   'infus',
#   'frida',
#   'visual',
#   'style',
#   'uniqu',
#   'inher',
#   'titular',
#   'charact',
#   'paint',
#   'process',
#   'creat',
#   'master',
#   'work',
#   'art'],
#  ['one', 'near', 'dread', 'expect'],
#  ['tri',
#   'captur',
#   'novel',
#   'deeper',
#   'intim',
#   'reson',
#   'film',
#   '--',
#   'iron',
#   '-',
#   'distanc',
#   'us',
#   'charact'],
#  ['real',
#   'women',
#   'curv',
#   'wear',
#   'empower',
#   'sleev',
#   'even',
#   'worst',
#   'harangu',
#   'easi',
#   'swallow',
#   'thank',
#   'remark',
#   'perform',
#   'ferrera',
#   'ontivero'],
#  ['whole',
#   'heap',
#   'noth',
#   'core',
#   'slight',
#   'coming-of-age\\',
#   'coming-out',
#   'tale'],
#  ['sensit', 'move', 'brilliant', 'construct', 'work'],
#  ['pull',
#   'rug',
#   'readi',
#   'hate',
#   'one',
#   'charact',
#   'realli',
#   'sympath',
#   'anoth',
#   'charact',
#   'someth',
#   'happen',
#   'send',
#   'differ',
#   'direct'],
#  ['art',
#   'direct',
#   'often',
#   'exquisit',
#   'anthropomorph',
#   'anim',
#   'charact',
#   'beauti',
#   'realiz',
#   'clever',
#   'makeup',
#   'design',
#   'leav',
#   'one',
#   'hope',
#   'eventu',
#   'dvd',
#   'releas',
#   'offer',
#   'subtitl',
#   'origin',
#   'italian-languag',
#   'soundtrack'],
#  ['probabl', 'easi', 'make', 'worthless', 'film'],
#  ['creativ',
#   'anim',
#   'work',
#   'may',
#   'look',
#   'fulli',
#   'render',
#   'pixar',
#   'industri',
#   'standard',
#   'use',
#   'light',
#   'effect',
#   'innov',
#   'background',
#   'equal',
#   'impress',
#   'degre'],
#  ['often', 'unfunni', 'romp'],
#  ['make',
#   'sens',
#   'went',
#   'back',
#   'school',
#   'check',
#   'girl',
#   '--',
#   'film',
#   'frat',
#   'boy',
#   'idea',
#   'good',
#   'time'],
#  ['clever', 'especi', 'compel'],
#  ['exit', 'sign'],
#  ['actor',
#   'showcas',
#   'accomplish',
#   'primari',
#   'goal',
#   'without',
#   'use',
#   'special',
#   'effect',
#   'rather',
#   'emphas',
#   'charact',
#   '--',
#   'includ',
#   'support',
#   'one'],
#  ['emperor',
#   'club',
#   'ruthless',
#   'placid',
#   'way',
#   'find',
#   'one',
#   'conserv',
#   'hidebound',
#   'movie-mak',
#   'tradit',
#   'give',
#   'new',
#   'textur',
#   'new',
#   'relev',
#   'new',
#   'realiti'],
#  ['half-an-hour',
#   'long',
#   'tv',
#   'special',
#   'humor',
#   'would',
#   'fast',
#   'furious',
#   '--',
#   'nineti',
#   'minut',
#   'drag'],
#  ['compel',
#   'mix',
#   'trial',
#   'movi',
#   'escap',
#   'movi',
#   'unexpect',
#   'fabl',
#   'ensur',
#   'film',
#   'never',
#   'feel',
#   'draggi'],
#  ['drown', 'sap'],
#  ['rare', 'bird', 'tri', 'forc', 'quirki', 'upon', 'audienc'],
#  ['solid', 'refin', 'piec', 'moviemak', 'imbu', 'passion', 'attitud'],
#  ['red', 'dragon', 'never', 'cut', 'corner'],
#  ['model'],
#  ['altern', 'medicin', 'obvious', 'merit', 'ayurveda', 'field', 'favor'],
#  ['bland', 'harmless'],
#  ['viewer',
#   'ask',
#   'often',
#   'suspend',
#   'belief',
#   'holm',
#   'perform',
#   'film',
#   'would',
#   'total',
#   'washout'],
#  ['small',
#   'fortun',
#   'salari',
#   'stunt',
#   'car',
#   'might',
#   'save',
#   'director',
#   'tom',
#   'dey',
#   'splice',
#   'togeth',
#   'bit',
#   'piec',
#   'midnight',
#   'run',
#   '48',
#   'hour',
#   '-lrb-',
#   'matter',
#   'shrek',
#   '-rrb-'],
#  ['good',
#   'see',
#   'michael',
#   'cain',
#   'whip',
#   'dirti',
#   'word',
#   'punch',
#   'peopl',
#   'stomach'],
#  ['thing',
#   'break',
#   'new',
#   'ground',
#   'tread',
#   'old',
#   'turf',
#   'like',
#   'hippopotamus',
#   'ballerina'],
#  ['film',
#   'exud',
#   'urban',
#   'sweet',
#   'woodi',
#   'allen',
#   'seem',
#   'bitter',
#   'forsaken'],
#  ['script', 'dim-wit', 'pair', 'teen-speak', 'anim', 'gibberish'],
#  ['cedar',
#   'somewhat',
#   'defus',
#   'provoc',
#   'theme',
#   'submerg',
#   'hoari',
#   'love',
#   'triangl'],
#  ['might',
#   'emerg',
#   'hilari',
#   'lunaci',
#   'hand',
#   'woodi',
#   'allen',
#   'mel',
#   'brook',
#   '-lrb-',
#   'least',
#   '70s',
#   'heyday',
#   '-rrb-',
#   'come',
#   'across',
#   'lame',
#   'sophomor',
#   'debut',
#   'indi',
#   'featur'],
#  ['disappoint', 'movi', 'long', 'time'],
#  ['comed', 'moment', 'romant', 'comedi'],
#  ['admir', 'yet', 'recommend', 'overstay', 'natur', 'run', 'time'],
#  ['plenti', 'enjoy', '--', 'small', 'part', 'thank', 'lau'],
#  ['action', '-', 'mechan'],
#  ...]

# %%
sent = []
for row in phrase:
    sequ = ''
    for word in row:
        sequ = sequ + ' ' +word
    sent.append(sequ)
    
phrase = sent
print(phrase[1])
# Out:
#  quiet introspect entertain independ worth seek

# %%
print(phrase[0], sentiment[0])
# Out:
#  seri escapad demonstr adag good goos also good gander occasion amus none amount much stori 1

# %%
X_train, X_test, Y_train, Y_test = train_test_split(phrase, sentiment, test_size=0.2, random_state=4)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
tfidf_vectorizer1 = TfidfVectorizer(min_df=5,
                                  max_df = 0.9,
                                  analyzer='word',
                                  strip_accents= 'unicode',
                                  ngram_range=(1,3),
                                  sublinear_tf=True,
                                  smooth_idf=True,
                                  use_idf=True,
                                  stop_words=None)

tfidf_vectorizer1.fit(list(fullSent['Phrase']))

train_tfidf = tfidf_vectorizer1.transform(X_train)
test_tfidf = tfidf_vectorizer1.transform(X_test)
print(train_tfidf.shape)
print(test_tfidf.shape)
# Out:
# (6823, 6856)
# (1706, 6856)

# %%
rX_train = train_tfidf.toarray()
X_train = rX_train.reshape(rX_train.shape[0], rX_train.shape[1],1)
print(X_train.shape)

rX_test = test_tfidf.toarray()
X_test = rX_test.reshape(rX_test.shape[0], rX_test.shape[1],1)
print(X_test.shape)

Y_train = keras.utils.to_categorical(Y_train)
Y_test = keras.utils.to_categorical(Y_test)
print(Y_train.shape, Y_test.shape)
# Out:
# (6823, 6856, 1)
# (1706, 6856, 1)
# (6823, 5) (1706, 5)

# %%
#Evaluation Metrics
import tensorflow.keras.backend as K # Import tensorflow.keras.backend instead of keras.backend

def recall_m(y_true,y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0,1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0,1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0,1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0,1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true,y_pred):
    precision = precision_m(y_true,y_pred)
    recall = recall_m(y_true,y_pred)
    return 2*((precision * recall)/(precision + recall + K.epsilon()))

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, MaxPool1D
from keras.layers import Activation, GlobalMaxPooling1D
from keras import optimizers
from tensorflow.keras.layers import Embedding
from numpy import newaxis

# %%
def baseline_cnn_model(fea_matrix, n_class, mode, compiler):
    model = Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(fea_matrix.shape[1],1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Activation('relu'))
    model.add(Dense(n_class, activation='softmax'))

    model.compile(loss = 'categorical_crossentropy', optimizer = compiler, metrics = ['accuracy', f1_m, precision_m, recall_m])
    return model

# %%
import math

lr = 0.01
batch_size = 64
num_epochs = 2
decay = math.exp(-4)
mode = "reg"
n_class = 5

adm = optimizers.Adam(learning_rate=lr, decay=decay)
sgd = optimizers.SGD(learning_rate=lr, nesterov=True, momentum=0.7, decay=decay)

model = baseline_cnn_model(X_train, n_class, mode, adm)

# %%
history = model.fit(rX_train, Y_train, batch_size=batch_size, epochs=num_epochs, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/2
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 33s 375ms/step - accuracy: 0.2797 - f1_m: 0.0283 - loss: 2.0391 - precision_m: 0.0937 - recall_m: 0.0245 - val_accuracy: 0.3201 - val_f1_m: 0.0042 - val_loss: 1.5162 - val_precision_m: 0.0909 - val_recall_m: 0.0021
# Epoch 2/2
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 33s 386ms/step - accuracy: 0.4647 - f1_m: 0.2616 - loss: 1.2910 - precision_m: 0.5399 - recall_m: 0.1896 - val_accuracy: 0.3297 - val_f1_m: 0.1744 - val_loss: 1.5839 - val_precision_m: 0.3730 - val_recall_m: 0.1144

# %%
preds = model.predict(X_test, verbose=0)

# %%
#Plotting Graphs
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])

plt.title('Model F1 Score')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(history.history['precision_m'])
plt.plot(history.history['val_precision_m'])

plt.title('Model Precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(history.history['recall_m'])
plt.plot(history.history['val_recall_m'])

plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()
